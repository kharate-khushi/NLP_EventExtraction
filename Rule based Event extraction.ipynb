# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.6.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)

# %%
import spacy

# Load the English model for spaCy
nlp = spacy.load("en_core_web_sm")

def extract_events_and_time(text):
    # Process the text using spaCy
    doc = nlp(text)

    # Extract named entities
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    event_entities = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ != "TIME"]
    time_entities = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ == "TIME"]

    return event_entities, time_entities

# Sample text for testing
text = "The meeting is scheduled for tomorrow at 2pm. John and Mary are attending."

# Extract events and time expressions
events, time = extract_events_and_time(text)

print("Events:", events)
print("Time Expressions:", time)
# Out:
# Events: [('tomorrow', 'DATE'), ('John', 'PERSON'), ('Mary', 'PERSON')]
# Time Expressions: [('2pm', 'TIME')]

# %%
import spacy
from spacy import displacy

# Load English tokenizer, tagger, parser, NER, and word vectors
nlp = spacy.load("en_core_web_sm")

# Example usage
input_text = "Indian Space Research Organisation (ISRO) is the space agency of India. The organisation is involved in science, engineering and technology to harvest the benefits of outer space for India and the mankind. ISRO is a major constituent of the Department of Space (DOS), Government of India. The department executes the Indian Space Programme primarily through various Centres or units within ISRO. ISRO was previously the Indian National Committee for Space Research (INCOSPAR), set up by the Government of India in 1962, as envisioned by Dr. VikramA Sarabhai. ISRO was formed on August 15, 1969 and superseded INCOSPAR with an expanded role to harness space technology. DOS was set up and ISRO was brought under DOS in 1972."
text = nlp(input_text)
displacy.render(text, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indian Space Research Organisation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (ISRO) is the space agency of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . The organisation is involved in science, engineering and technology to harvest the benefits of outer space for
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and the mankind. ISRO is a major constituent of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Department of Space
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (DOS),
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Government of India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . The department executes
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Indian Space Programme
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  primarily through various
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Centres
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  or units within
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ISRO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . ISRO was previously
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Indian National Committee for Space Research (INCOSPAR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), set up by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Government of India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1962
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , as envisioned by Dr. VikramA
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sarabhai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . ISRO was formed on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     August 15, 1969
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and superseded INCOSPAR with an expanded role to harness space technology.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DOS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was set up and ISRO was brought under
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DOS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1972
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div></span>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import spacy

# %%
! pip install jsonlines
# Out:
# Collecting jsonlines
#   Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines) (23.2.0)
# Installing collected packages: jsonlines
# Successfully installed jsonlines-4.0.0

# %%
import jsonlines

def load_data(file_path):
    data = []
    with jsonlines.open(file_path) as reader:
        for obj in reader:
            data.append(obj)
    return data

# Load training, validation, and test data
train_data = load_data('/content/drive/MyDrive/Dataset/train.jsonl')
valid_data = load_data('/content/drive/MyDrive/Dataset/valid.jsonl')
test_data = load_data('/content/drive/MyDrive/Dataset/test.jsonl')

# Example: Print the first instance in the training data
print(train_data[0])
# Out:
# {'title': '2006 Pangandaran earthquake and tsunami', 'id': '8307a6b61b84d4eea42c1dd5e6e2cdba', 'content': [{'sentence': 'The 2006 Pangandaran earthquake and tsunami occurred on July 17 at along a subduction zone off the coast of west and central Java, a large and densely populated island in the Indonesian archipelago.', 'tokens': ['The', '2006', 'Pangandaran', 'earthquake', 'and', 'tsunami', 'occurred', 'on', 'July', '17', 'at', 'along', 'a', 'subduction', 'zone', 'off', 'the', 'coast', 'of', 'west', 'and', 'central', 'Java', ',', 'a', 'large', 'and', 'densely', 'populated', 'island', 'in', 'the', 'Indonesian', 'archipelago', '.']}, {'sentence': 'The shock had a moment magnitude of 7.7 and a maximum perceived intensity of IV ("Light") in Jakarta, the capital and largest city of Indonesia.', 'tokens': ['The', 'shock', 'had', 'a', 'moment', 'magnitude', 'of', '7.7', 'and', 'a', 'maximum', 'perceived', 'intensity', 'of', 'IV', '(', '``', 'Light', "''", ')', 'in', 'Jakarta', ',', 'the', 'capital', 'and', 'largest', 'city', 'of', 'Indonesia', '.']}, {'sentence': "There were no direct effects of the earthquake's shaking due to its low intensity, and the large loss of life from the event was due to the resulting tsunami, which inundated a portion of the Java coast that had been unaffected by the earlier 2004 Indian Ocean earthquake and tsunami that was off the coast of Sumatra.", 'tokens': ['There', 'were', 'no', 'direct', 'effects', 'of', 'the', 'earthquake', "'s", 'shaking', 'due', 'to', 'its', 'low', 'intensity', ',', 'and', 'the', 'large', 'loss', 'of', 'life', 'from', 'the', 'event', 'was', 'due', 'to', 'the', 'resulting', 'tsunami', ',', 'which', 'inundated', 'a', 'portion', 'of', 'the', 'Java', 'coast', 'that', 'had', 'been', 'unaffected', 'by', 'the', 'earlier', '2004', 'Indian', 'Ocean', 'earthquake', 'and', 'tsunami', 'that', 'was', 'off', 'the', 'coast', 'of', 'Sumatra', '.']}, {'sentence': 'The July 2006 earthquake was also centered in the Indian Ocean, from the coast of Java, and had a duration of more than three minutes.', 'tokens': ['The', 'July', '2006', 'earthquake', 'was', 'also', 'centered', 'in', 'the', 'Indian', 'Ocean', ',', 'from', 'the', 'coast', 'of', 'Java', ',', 'and', 'had', 'a', 'duration', 'of', 'more', 'than', 'three', 'minutes', '.']}, {'sentence': 'An abnormally slow rupture at the Sunda Trench and a tsunami that was unusually strong relative to the size of the earthquake were both factors that led to it being categorized as a tsunami earthquake.', 'tokens': ['An', 'abnormally', 'slow', 'rupture', 'at', 'the', 'Sunda', 'Trench', 'and', 'a', 'tsunami', 'that', 'was', 'unusually', 'strong', 'relative', 'to', 'the', 'size', 'of', 'the', 'earthquake', 'were', 'both', 'factors', 'that', 'led', 'to', 'it', 'being', 'categorized', 'as', 'a', 'tsunami', 'earthquake', '.']}, {'sentence': 'Several thousand kilometers to the southeast, surges of several meters were observed in northwestern Australia, but in Java the tsunami runups (height above normal sea level) were typically and resulted in the deaths of more than 600 people.', 'tokens': ['Several', 'thousand', 'kilometers', 'to', 'the', 'southeast', ',', 'surges', 'of', 'several', 'meters', 'were', 'observed', 'in', 'northwestern', 'Australia', ',', 'but', 'in', 'Java', 'the', 'tsunami', 'runups', '(', 'height', 'above', 'normal', 'sea', 'level', ')', 'were', 'typically', 'and', 'resulted', 'in', 'the', 'deaths', 'of', 'more', 'than', '600', 'people', '.']}, {'sentence': 'Other factors may have contributed to exceptionally high peak runups of on the small and mostly uninhabited island of Nusa Kambangan, just to the east of the resort town of Pangandaran, where damage was heavy and a large loss of life occurred.', 'tokens': ['Other', 'factors', 'may', 'have', 'contributed', 'to', 'exceptionally', 'high', 'peak', 'runups', 'of', 'on', 'the', 'small', 'and', 'mostly', 'uninhabited', 'island', 'of', 'Nusa', 'Kambangan', ',', 'just', 'to', 'the', 'east', 'of', 'th ...

# %%
import json

# Assuming dataset is a list of dictionaries
for data in train_data:
    # Accessing elements within each dictionary
    print(data['id'])
    print(data['title'])
    for content in data['content']:
        print(content['sentence'])
        print(content['tokens'])
    for event in data['events']:
        print(event['id'])
        print(event['type'])
        for mention in event['mention']:
            print(mention['id'])
            print(mention['trigger_word'])
    for negative_trigger in data['negative_triggers']:
        print(negative_trigger['id'])
        print(negative_trigger['trigger_word'])
# Out:
# Streaming output truncated to the last 5000 lines.
# b226e4064cbd1e513c5a612e77bd24fb
# Getting
# 70609cefacbdf09c2c0663a3fe8f9cf4
# made
# 094f2c388aec22cf43eaae719b0bb9d5
# Motion_directional
# 05d6499add609ac3ea70c5892f3c0881
# climbed
# ca20fb0d516a9170946bbbbf9c1aac6e
# Getting
# 9e85cf3d03c549a2d836b4918edc10f0
# tied
# c090f9f90b96df59a8b64bd7b8956092
# Defending
# fad3c5c249e9b6272ea2b7cf389bf0e6
# defense
# 7b9b6b6b6275b6b77394b921e2a22d1d
# Participation
# 2faf862b233bf20501d692aa20a63545
# enter
# 925a7c77e4f5da3f801222f33816e84b
# Self_motion
# f3cd95133a1066ebb2eb78221cc94021
# made
# 7d9e46519352e2c5d668584591d4443d
# Social_event
# 1d847d2780bd781b9ff5f651fe434309
# hosted
# be23a4408ba47e4e09ddb7721ba2bc64
# Social_event
# 4fd05744d3b60396d91e026464aff9cc
# hosted
# c6c4d8c0e8def34395209403362c960f
# U.S.
# 32131719ff7aea298d9bceabeee53d24
# Open
# 83c4ed43377346d6c8138d982ae3e63c
# 61st
# 216bb9b2cab831f78dfe8c5072a004d4
# U.S.
# 688e1305536b187f21be83d6d6cd814f
# Open
# 21a4d3aea7fd986101eb0ebb99e1efd5
# June
# 42e963d421330fbba5ffabe3af20e679
# South
# 1b84921f195aee5a9f798e6dc02ba83b
# Course
# be26a0b7d7269455163519dce12a8151
# Oakland
# 2180b221efc94417b78c7cdc2767c37f
# Hills
# a75e883a49dc659354cd4320ec952707
# Country
# a1e73aac651042472f33a37b5ea2d4c4
# Club
# 5cb00cf3b7f894f0fd33cd861ed8fec3
# Birmingham
# ee7b43ce6ef33e8e3e5a25969b75a096
# Michigan
# 7120724306d53bfde0da073f1b62fae2
# suburb
# 094eb0c08afe90c170fcbc296caa8d37
# north
# 95295ba1141424f6ba25e06357452b9c
# Detroit
# 1176a1e8bcd0d0b9d8ce51ac4dd7e859
# gene
# b08c2b4a243745f301dba829f3c9a402
# littler
# 401fd788c533b7abda2d4ed1bc7ad267
# final
# 39583a1626a0208c7810ddaafca494a4
# round
# 8c94608f809ae1867e24a238bab3a78b
# +1
# 80ce5724557577647c3fa5262cb4a68d
# sole
# 6bb397a315a8f876ead6a5c5e46452c2
# major
# fe27dc7fa4e7d46dc174376b648df188
# title
# cdd92e6e09473ebf1d8b786476b659e5
# stroke
# bda65d9a19379f7dec44fe5fbad220cf
# ahead
# e314af6e56a64c8843e61e2c37ae77c3
# runners-up
# 8a15abdf293b02e30ab64438de9c0471
# bob
# 8a76a9a170560fe1ed8e9308c331eb8a
# goalby
# 1e1862da4df1b2ac66c82a829005e0c5
# doug
# c991e46dded80c62ea8b5992981124af
# sanders
# 8cae86927ffac683999010156fa35fb1
# 54-hole
# 40f54cbb5a7ecc43cfc84a7e0497ad54
# leader
# 4fd67bad3152ff1f4cdab98cb242fbb9
# amateur
# 661420c9fe0470af51111fbaa23bb5f9
# jack
# a7acf0cb7261d15be7d8c21df0e377f8
# nicklaus
# afd51f026b971588b2572757ed3d3c6b
# fourth
# c1322fa7ade2c824f157816b0607bbd4
# age
# 79bb7f5346d78c98f3038d8700ed1d91
# second
# bbba85c6653e3fac3a51d1bd50d3fde6
# consecutive
# 51ecb4c41e2e693eee7e4d737c8040a4
# unk
# d88fbd7b43db7139c0936f239a916934
# finishes
# 51f5013f2794a7fb05dfc01cbd8374ba
# u.s.
# 6bca56ac4d0e52453d73c6110d785b01
# runner-up
# b2fc23ee9442c4c30d8b01645eadcfb7
# previous
# 8431f3270f7cbd5cd2a0f27af96f9e56
# year
# b6c6a474be35acee2583d7d1e874f8f3
# professional
# b98ce9a681aee3524d3dab687a46c4ed
# November
# 119d61fbcaaab11199035008e643619b
# first
# a832e143e3ae8a1ddf0235044cc9c754
# U.S.
# 0d959e1671b77536f3ed9d0b7a5b3327
# Open
# 67d5db726f183de2fb3f0d64813bb757
# titles
# 0d27fbf5d9556188ff6cb8a75f89867d
# following
# ffd35c4eda566728ead10b40f717171f
# year
# d8c8dbfbc7ddbe68603123e895b8f06f
# Defending
# 8a1674ebc3945c26302096cb53d4c755
# champion
# d174315373eae1043ee54872dc9653f1
# Arnold
# 89ba66c4f79da0fbcdbe4fcd2aa9e619
# Palmer
# 28bdaa8c0d75cefd8b16d1849bb87740
# cut
# 2f2f7e6ab0719a017d6be12ea2f2185e
# number
# 7eb65e00c0c166f7c3667f32111a0f9f
# +9
# e737f656795f84ff584dd22bf6680c12
# even-par
# 0ab18c8e204191fa81c64cb5665121cb
# twice
# e01a4a69b5d4dd56028ca6c1f361fd2b
# tie
# 83884088a3a2f1f7f9baae95dd927040
# place
# 77f95f14b9539b0f04a0f87413011a7a
# strokes
# 5d9be582cb64a62bdb30c3169bada58b
# Littler
# 56ab920d67745438dd700a6a9b4cfdf2
# Four-time
# d8684209ce37a2b408111d99fcfeffcd
# champion
# d5f43f6069ec1d38ef70a15c06c88d6f
# Ben
# a80aebc5854fca00a496a1477b0b1ebf
# Hogan
# 599c1c933c7c5fe722067a6c9faa928a
# also
# 2a2ad5e60452d1511a64cc874c5d1fae
# time
# 79aba6da34056089b6d9fe0a3fac9796
# top
# d49d7e4aaa2c81e192ffb96948002188
# ten
# 9fe3f4e2762cd6a64842805068c7a237
# major
# c23ce74d8da46577d66dc80489f4b855
# course
# 9b8d31738ad68f6eaf88c25500a97a89
# site
# 749562fda5c0ea714c74db80b7792a60
# third
# e19bc3482205ea8f84335a3bb5ad5855
# title
# 7864dadd24e8cbea7082ce34ec9d0ff8
# decade
# dc8295ec163655b42b50eadef7b169e6
# earlier
# f3a72f4429f9ddf66d8345cbffd19253
# rare
# 0b39820105157584d2cdd6c8492101bb
# successful
# 16da65a88844e2f5b2809a85c8c34d69
# Hogan
# a95c663ffc8276e127428862c854c187
# years
# 1fedae237e3be74d9fdfcca5afb7ae67
# final
# 3a08b077ee7a6d8d918d6afc82e8c4c2
# U.S.
# 68e69adb05027bb1fc4f2bff5a7aa1ca
# Open
# b00d2e8abbabd4ca2d30232cb6e6a501
# appearances
# 10b73502a63de767ad6ef3757999a912
# South
# 79986e3b4ba2e81285a6846f1952d03a
# Course
# 5a1b95083d90bc448371bac3a5faeca4
# previously
# 3d0294e5a3a365479a56a0977b84a20b
# U.S.
# 67c355dff8d6a33e6bfcafac4039a32d
# Open
# 456f53b178ddb2e4c99c27c9e554251b
# later
# 37722c75979ce0e688318a6ef9547212
# PGA
# d512d21bc4504f1182877d6db12e0f6b
# Championship
# 1d19d614c16e453285d1cdfba2be84c6
# Curling at the 2014 Winter Olympics
# The curling competition of the 2014 Winter Olympics was held at the Ice Cube Curling Center, nicknamed "the Ice Cube".
# ['The', 'curling', 'competition', 'of', 'the', '2014', 'Winter', 'Olympics', 'was', 'held', 'at', 'the', 'Ice', 'Cube', 'Curling', 'Center', ',', 'nicknamed', '``', 'the', 'Ice', 'Cube', "''", '.']
# It is the sixth time that curling was on the Olympic program.
# ['It', 'is', 'the', 'sixth', 'time', 'that', 'curling', 'was', 'on', 'the', 'Olympic', 'program', '.']
# In both the men's and women's competitions, ten nations competed.
# ['In', 'both', 'the', 'men', "'s", 'and', 'women', "'s", 'competitions', ',', 'ten', 'nations', 'competed', '.']
# These two events took place from 10 to 21 February 2014.
# ['These', 'two', 'events', 'took', 'place', 'from', '10', 'to', '21', 'February', '2014', '.']
# The Canadian women's team went through the whole competition undefeated, the first time this has happened in an Olympic women's curling competition.
# ['The', 'Canadian', 'women', "'s", 'team', 'went', 'through', 'the', 'whole', 'competition', 'undefeated', ',', 'the', 'first', 'time', 'this', 'has', 'happened', 'in', 'an', 'Olympic', 'women', "'s", 'curling', 'competition', '.']
# Additionally, both the Canadian men's and women's teams won the gold medal, becoming the first country to do so in the history of the event.
# ['Additionally', ',', 'both', 'the', 'Canadian', 'men', "'s", 'and', 'women', "'s", 'teams', 'won', 'the', 'gold', 'medal', ',', 'becoming', 'the', 'first', 'country', 'to', 'do', 'so', 'in', 'the', 'history', 'of', 'the', 'event', '.']
# c722faed6fc3d27ce2a4d42a1a204f0a
# Competition
# 7f63fe5ca228b0fba19d64bfdde7b7fe
# competition
# 0cdb1d7ab3924b0eff45ca5c6c64d2ab
# Name_conferral
# 7932bbf80995d15ffd6cb59049dc0d98
# nicknamed
# 02d9b8dde5a226377d39d7011d8ac9ef
# Competition
# 64dfb55d952f41d4b08bafcae03961bd
# competed
# 1fa3ed1ca8bba32d7cd2fcb6c43a3859
# Becoming
# c9d8b0d1d3b9c8c5474b0220e17e4805
# becoming
# 4784744ddc2b6bc9cf4050b8a72a1ef4
# Process_start
# 4813858f4906fcbc5a1756432dec3b2d
# took place
# 1f8fe02a733f469299371cc14b7628c7
# Presence
# 7830a2ba7ed7b8292cdb7908449db900
# happened
# e73970dc7f413dfd6bbf35ee3ff16110
# Hold
# 2ce8c5fa58cb0d9dcd1584f05a6a1969
# held
# 852a50785ef83fa4f0ce31a224130f52
# undefeated
# f25f8d534c79c399d9ea5d84240e1cb4
# went through
# 19f3b37aacbcc09cbfa2fe53d0ec5efd
# curling
# 3d5d4c3cafc81ae17dcb5702e370c8f2
# Winter
# e93caf081a46c60d50ae999302e66810
# Olympics
# 5e1b060f4aec2960bc24d2fdef9952a0
# Ice
# 92145bef353d9826e0fb82e267b23553
# Cube
# 96ffc09c9b8e3efab50e47dee9d5079c
# Curling
# b9808b975e8b07556b3833a7d2ba1e2f
# Center
# cce9b117273071569b948a77f75c044c
# Ice
# bd0e6d034c4a22aaedc36abdae406078
# Cube
# 532acd7b6dbfd510eb4db3cc2607de55
# sixth
# 0c04cdcf8d057a258522d76caffdd5d2
# time
# 1ec204d076e6e3d32cf1d2ffaa740895
# curling
# fd05228f14ac73bccd8f7168a9c7f291
# Olympic
# f546f2437e760a05df9905bb8fea8b64
# program
# a22b81fcfc65259b0db543b6d99775e6
# men
# 7580d2f7ed4bbff1351655ec94dea95b
# women
# 46c44326657b28e3c0a8b33ba4757d8a
# competitions
# c43fa4d9de735fbe07ca0dbb781a8c15
# ten
# 8bd618d045e7a8a4fb4b68e95391bbcc
# nations
# 68e99f250126ccd43194e91d2337393e
# events
# 6b6cce1bdc73bba5f82f90e87cdb21b9
# February
# 2e976b7efd65a05f82d3a65234d11374
# Canadian
# a879db283a5add2b998c0c8b1ceddabe
# women
# 984b89390cf2d468f4c84e9eec56ec69
# team
# df78f04b02d900b9eb3574d15189c6a7
# whole
# 1da3a1268f7ff9521d3311353ab8d9f9
# competition
# cf867f4332070320b96393dd1a843bcd
# first
# 9eeede1912e5d5fa5ed6e9bd9d08f0ce
# time
# bb60bdd7199148cd31c8b466dac43fb5
# Olympic
# 1cebf544925457990a74f8ebaa3d777c
# women
# 167d1c36ea9de76b81ba19db62cbcb9c
# curling
# 2dbfb81efa98d13ec3f9c12474f8e5bf
# competition
# 9d7558d38ac1caa655b056dd1d3afcdf
# Additionally
# 37aa549971d176ad81f70408607cd466
# Canadian
# 40ec71bc0e4c44bd8a59eaf343c5ed60
# men
# 9b82201bb4072b68daab6b1601c63d58
# women
# b72b3fce1120217908e6299f482ec858
# teams
# 9ae5ba3224cb4cc4eefc8ab483394d64
# gold
# c45ffa99455ea64c2cfb725eaadf1679
# medal
# 7a1da47460059eb9dab0f91d469be39e
# first
# ada51fdd36f3bc2acdbabe4970772f39
# country
# 8340038f890ec82821440ed9f00dc257
# history
# 3d03a4ee3e7fbdd73463deb599224cdd
# event
# e005b9066a4a28293164fb3430e5cc6c
# Baseball at the 1992 Summer Olympics
# Baseball had its debut as an official medal sport at the 1992 Summer Olympics in Barcelona.
# ['Baseball', 'had', 'its', 'debut', 'as', 'an', 'official', 'medal', 'sport', 'at', 'the', '1992', 'Summer', 'Olympics', 'in', 'Barcelona', '.']
# Eight nations competed, with the preliminary phase consisting of each team playing every other team.
# ['Eight', 'nations', 'competed', ',', 'with', 'the', 'preliminary', 'phase', 'consisting', 'of', 'each', 'team', 'playing', 'every', 'other', 'team', '.']
# Playoffs were then held, with the four highest ranked teams advancing.
# ['Playoffs', 'were', 'then', 'held', ',', 'with', 'the', 'four', 'highest', 'ranked', 'teams', 'advancing', '.']
# For the semifinals, the 1st place team played the 4th place team and the 2nd place team played against the 3rd place team.
# ['For', 'the', 'semifinals', ',', 'the', '1st', 'place', 'team', 'played', 'the', '4th', 'place', 'team', 'and', 'the', '2nd', 'place', 'team', 'played', 'against', 'the', '3rd', 'place', 'team', '.']
# The winners of those semifinals competed against each other for the gold medal, with the loser getting the silver medal.
# ['The', 'winners', 'of', 'those', 'semifinals', 'competed', 'against', 'each', 'other', 'for', 'the', 'gold', 'medal', ',', 'with', 'the', 'loser', 'getting', 'the', 'silver', 'medal', '.']
# The teams defeated in the semifinal played a match for the bronze medal.
# ['The', 'teams', 'defeated', 'in', 'the', 'semifinal', 'played', 'a', 'match', 'for', 'the', 'bronze', 'medal', '.']
# Baseball was an event open only to amateurs.
# ['Baseball', 'was', 'an', 'event', 'open', 'only', 'to', 'amateurs', '.']
# af9a850399747d9c70b61c1e1f6f7ef4
# Process_start
# 4307cbd4bf81b0d4d89f73cf0a782ebc
# debut
# ac38b86084659371ff37050b28dd378c
# Competition
# ae66fd42c8088d014d4bf57f027f5312
# competed
# 9f44ca450b0e4485719fc3707be9b864
# Competition
# 025b7a36c6addb3703dc1691bc546f47
# played
# 8cdfb019bf5a70d19e0dca70d42a72a5
# Competition
# 57571c06a1edf7f0f321b7e57a1fa38a
# played
# fdcb11928c2a8ccb261372879392851e
# Competition
# fc20fd5a9dd3a741ddb0808eb3b83210
# competed
# a0183c41fa2e94bbae20491d4fd9c301
# Competition
# d40843f384faf8cb09286bbee9830564
# played
# 5b131a63bba8127248794ced0b6d9f31
# Hold
# 172ac0ed00728c053c5afb979907fff7
# held
# 7526c2c6ac81a21651dc5eff00cbf79b
# Baseball
# 281e2397f400014e37c24380610bfb32
# official
# ec898d1d6c6aa5c538934b2f40b7f979
# medal
# 941f721e75842385d758c2bbfeaffeae
# sport
# 22c8359d70e300bd3edd752a5fa9309c
# Summer
# bc95958c2f9a7074c440d486c9d0aadc
# Olympics
# ab963737cae2b5aa761c8eed4340ab0e
# Barcelona
# abc46dac02a9d5b629a51c20227ada7c
# nations
# 13637d86a24b0149765fca0f306dc235
# preliminary
# e114f483e7c8b78a3c4a09bd715efed3
# phase
# 5ac4562b81ee45a7a799af3d64b678bf
# consisting
# 34a85aa646c80c4c240715a5309e0ed0
# team
# 50343868b90ce483c2f0602cfdaa2b8e
# playing
# 6e4be90ec4fcf5de3641384b80ddf475
# team
# c6e645331a544ddbba1fbe40240d8d6c
# Playoffs
# 2806c3c636d61337994c97ad2ccc43d3
# highest
# 65464b56cb8bd163c9257a3e7de5e317
# ranked
# 5e8320b55506384cca25c93664d9c94b
# teams
# ee1c571a99fe6bb4cdd3338c806ffa8e
# advancing
# e4539d95cda2878033c280710746c32f
# semifinals
# db0f0cb5292a29d526f17ceb5cb072cf
# place
# b3b46208a007c1fbd802025420e900de
# team
# 9a4c2a12766f8237d233d8d2832bd9e4
# 4th
# 51719e99dc3957aa1003a69a31571428
# place
# 18e2438b500a21ede44fda00d6a34f5d
# team
# d5bf0b7d7e2c86b86a8fc180546be0f2
# 2nd
# 581d0b2a446a89ed18e0a96fff885376
# place
# 33a1f4df243452ea967baa654d0b5960
# team
# feb0a4c0588970f0603e5d3930960ef2
# place
# 0274d6898c92a88da231a76bee77ceaf
# team
# 4ebcfb1b45e23115c16827f4e7a3b32e
# winners
# 06361bf687e4c2bedf7a44189022d897
# semifinals
# a1eb4eeee1512709803de1504e66597a
# gold
# 8c399c0717be2975a14225c625c57da8
# medal
# 0a8a6d898769f8bcf3d3358f5fc702ae
# loser
# 5246501e652d9a9fa2dbaaa856cabb20
# getting
# 5d1c587d275df23939e71c66fad94a69
# silver
# f235522ca81230bfd8375b6df8532fe1
# medal
# 384db90aba34f52ff3b1a565e0cd62d7
# teams
# 089eb6fc271a7a7d540c1c99689a6133
# defeated
# 7d0cc7d8bcdb4d5cbe9632e311621879
# semifinal
# d0f00383c4d844d2159cb9f1a037016e
# match
# cce72b08778041a57b10fe9a7a253a6b
# bronze
# e032e94e1e3877d69fad2a77bb718021
# medal
# 29f11048994abb40ad93762fd0af386f
# Baseball
# 1f6981948b58f785948eb39669b7a4bf
# event
# ca815a4addcd22f93c0c39edd3f6dd89
# open
# 8826356ef4ccbb9062d718ba099f1443
# amateurs
# 455424db29bf4f877f82a03e6778ca26
# Reunion Tour (The Stone Roses)
# The Reunion Tour was a rock concert tour by The Stone Roses.
# ['The', 'Reunion', 'Tour', 'was', 'a', 'rock', 'concert', 'tour', 'by', 'The', 'Stone', 'Roses', '.']
# Three homecoming shows in Heaton Park, Manchester and a show in Phoenix Park, Dublin were the first shows to be announced by the band.
# ['Three', 'homecoming', 'shows', 'in', 'Heaton', 'Park', ',', 'Manchester', 'and', 'a', 'show', 'in', 'Phoenix', 'Park', ',', 'Dublin', 'were', 'the', 'first', 'shows', 'to', 'be', 'announced', 'by', 'the', 'band', '.']
# Fifty shows eventually took place in Europe, Asia, North America and Oceania.
# ['Fifty', 'shows', 'eventually', 'took', 'place', 'in', 'Europe', ',', 'Asia', ',', 'North', 'America', 'and', 'Oceania', '.']
# The Heaton Park shows currently hold the record for the fastest selling rock gigs in UK history.
# ['The', 'Heaton', 'Park', 'shows', 'currently', 'hold', 'the', 'record', 'for', 'the', 'fastest', 'selling', 'rock', 'gigs', 'in', 'UK', 'history', '.']
# The "Irish Independent" described the Dublin leg of the tour as "one of the most anticipated gigs of the year."
# ['The', '``', 'Irish', 'Independent', "''", 'described', 'the', 'Dublin', 'leg', 'of', 'the', 'tour', 'as', '``', 'one', 'of', 'the', 'most', 'anticipated', 'gigs', 'of', 'the', 'year', '.', "''"]
# The Stone Roses have also re-entered the music charts on the back of the tour.
# ['The', 'Stone', 'Roses', 'have', 'also', 're-entered', 'the', 'music', 'charts', 'on', 'the', 'back', 'of', 'the', 'tour', '.']
# 73dcae4bdce67f603bcef5d68308f609
# Process_start
# a8a3c1f0a5c06503c7dad7ef6c007f65
# took place
# 66165f82a7672ced345f96a88727c6d2
# Expressing_publicly
# e859900e33e963e59356bd7b19fb6548
# announced
# 07b6a2eceb1d2cdf440162b8ff1bf023
# Statement
# 806470c73e4661a18fe753f5b79792bc
# described
# 7fe70b46ffdeceab9ae1918e18123a3f
# Hold
# 4caaaf907de02c0dee0ce7fc980e4469
# hold
# 4bbdf83c14ffc3f92dc97d40615caf27
# Arriving
# 182b1a9a4c6659695caf8c3ace3e428e
# re-entered
# 25c0da95d705204a87442b824beb4ad5
# Reunion
# df04df0f0926ed8bdaeea70474ed502e
# Tour
# a960ec6c85332613e03e1db365ef0911
# rock
# ae87ee77911168a212fb5411aec5292f
# concert
# c38246d2c6172f1f7787809f9d516a0e
# tour
# c1a77bd07d52435a651116c3fea20d81
# Stone
# c2d463b228bbb36931378788998466fb
# Roses
# 62f5045577883782fe8286352d70c7fd
# homecoming
# 703210b070f3152bc28a04939d5b84a8
# shows
# c02fcd46989396fcbef1cf32e35d379f
# Heaton
# 1d560aba96383f3c4f0289a0c96c3e93
# Park
# fd39759567f949988b8699047d504a48
# Manchester
# 37fec6a86b527a0e46d791d61358dc6e
# show
# 8e7ed476e4c79ec3553e3c28dd1b7434
# Phoenix
# 35ebb7f04d975b45f2f4a1e1367e42da
# Park
# 8f9d17309b0ed9a3c8d3ee2c60bcc2c3
# Dublin
# 3a4239e7dc2c0674d7a0625ccda07a92
# first
# 548bac90ecc51af36a371f21201e7c6c
# shows
# 56f0b2582f6070a8fc5fe912fadd7b1d
# band
# 82ad4b86b315f148b3ecd7c6f72d76c1
# Fifty
# 1be265c7a396af5c7f5275279b5ecf29
# shows
# 60e6831d504a49dd5cd241b09ab6507f
# eventually
# 4a01535011897a471045c585e31b85f9
# Europe
# 851480ddb48ee23d6ebe424624698263
# Asia
# 4eab25da557168e1eb80dbb3a7d06267
# North
# b6eff9d5f1fe3505b5cbc982d48a23d7
# America
# e950e96d57438b7438c1b640f23cb502
# Oceania
# 56c9bd0b81c541b7a39d9bf3b17b340b
# Heaton
# 6f4c414b916cad3777a85c524de654c0
# Park
# b235f54c31701fda8831c56618c93a43
# shows
# 67bef257dfaab96e16ff960169192e10
# currently
# 6aeb6f83668c2ef96c714185a2078788
# record
# e01fe60a62e125428553815947ad8f1f
# fastest
# dbcc19d0b617d6794e3a0fc96b725396
# selling
# 4e46d0472872c9cdd57ce3bab1c2d4be
# rock
# 3df328195ae05011156d999ab8f7383d
# gigs
# 221bb841887209c4afd88ea583e22142
# UK
# 52738c6ce3c5b91012f0a3a0312a6367
# history
# 9b10f464118bfb3cbf5dffa82960f2fc
# Irish
# 608fe6828dcad2cd2480d404a6499dc3
# Independent
# 49f03a40a9e49db1a3fc147425776a43
# Dublin
# 2bd9cacabb4979719d8ba2d3577c138c
# leg
# d6c54b1dc2711ac9bc63b993bcd1c033
# tour
# 4c8f1bca3e75de33906c94018d874084
# anticipated
# 8f3afac2c3bd9b9ca2704f3c9f4293fa
# gigs
# c0e7d80777a40ed6024535c679b006dc
# year
# 49db21da395c257b35375e284b1d02a2
# Stone
# cb35f9f9b4b2c2ec799a305ee566828c
# Roses
# e8d236bbd2120a39a5c6cb686354c672
# also
# f614e8b0485a3ebe7f8c0dd59cc5f1e7
# music
# f65de045ac399fd454ea3aec3b5e1352
# charts
# 317b14143bef07cca55058d1f2849bfa
# back
# 8e29e6a5f84d0895b5e1e5f939e9c30c
# tour
# 1f0bac3122d16d42e93152945b5dfd68
# 2009 Peace Cup
# The 2009 Peace Cup Andalucia was an invitational friendly football tournament.
# ['The', '2009', 'Peace', 'Cup', 'Andalucia', 'was', 'an', 'invitational', 'friendly', 'football', 'tournament', '.']
# It was the fourth edition of Peace Cup and was held in Spain from 24 July to 2 August in the cities of Madrid, Seville, Málaga, Jerez and Huelva.
# ['It', 'was', 'the', 'fourth', 'edition', 'of', 'Peace', 'Cup', 'and', 'was', 'held', 'in', 'Spain', 'from', '24', 'July', 'to', '2', 'August', 'in', 'the', 'cities', 'of', 'Madrid', ',', 'Seville', ',', 'Málaga', ',', 'Jerez', 'and', 'Huelva', '.']
# It was the first time that the tournament has been hosted by a nation other than South Korea.
# ['It', 'was', 'the', 'first', 'time', 'that', 'the', 'tournament', 'has', 'been', 'hosted', 'by', 'a', 'nation', 'other', 'than', 'South', 'Korea', '.']
# The winners of the tournament were Aston Villa, who defeated Juventus in the final.
# ['The', 'winners', 'of', 'the', 'tournament', 'were', 'Aston', 'Villa', ',', 'who', 'defeated', 'Juventus', 'in', 'the', 'final', '.']
# They succeeded Olympique Lyonnais, who were the previous holders of the tournament through winning the 2007 edition.
# ['They', 'succeeded', 'Olympique', 'Lyonnais', ',', 'who', 'were', 'the', 'previous', 'holders', 'of', 'the', 'tournament', 'through', 'winning', 'the', '2007', 'edition', '.']
# It was one of seven 2009 pre-season friendly tournaments, the others being the Emirates Cup, the Barclays Asia Trophy, the World Football Challenge, the Wembley Cup, the Amsterdam Tournament and the Audi Cup.
# ['It', 'was', 'one', 'of', 'seven', '2009', 'pre-season', 'friendly', 'tournaments', ',', 'the', 'others', 'being', 'the', 'Emirates', 'Cup', ',', 'the', 'Barclays', 'Asia', 'Trophy', ',', 'the', 'World', 'Football', 'Challenge', ',', 'the', 'Wembley', 'Cup', ',', 'the', 'Amsterdam', 'Tournament', 'and', 'the', 'Audi', 'Cup', '.']
# c6d147840f31e0f443b8139c4b3c0880
# Competition
# ebd7fc02672f2a41e423bdd5cc3aa5e3
# tournament
# 3442558d13b0dbddfddedae05d808b74
# tournament
# 59457421f60c2faa5e33e44f18ad9214
# Conquering
# 8a2861176978ea0baa88c277d9c950aa
# succeeded
# 460ee8c121f94078e6ebc607734ac1ec
# Hold
# 3fb9d47a3b786e8ed7e6c272fd229e90
# held
# 567acb29434a60dd2be18e8a40cc14ed
# Social_event
# eb705d4c2675961afed2e761f461fdf9
# hosted
# da542c233e28fc5a923e27d35c30d5a9
# Conquering
# f5471fe26baa73f528fe599e131f5578
# defeated
# fd629f602128b29d23eaf16b022881e1
# Competition
# b9e74d9baa14341344827766c634b597
# final
# 714a731fa8ef595802070a4148c8ca90
# Getting
# 0f696211bd63f04f039aaf856ceeb9bf
# winning
# 2c3226f2c25f09d1512604b72dcf263a
# Peace
# 90f02cd894a35d8ff215f1755f87db50
# Cup
# 7cb369fafa677ce4fafb661c8e544064
# Andalucia
# 3d998a5c8ea7bdc916a71ccb656b5097
# invitational
# 41b22e2fee8600cc1d5358b7df58a77e
# friendly
# 92f1537da7ba6d229e9be7179a0c366b
# football
# fa700497f3fdcbc723bf3c5bdd3e96c5
# fourth
# 400e05f5709101ec570af6b1066736bf
# edition
# 6e547bc88bceb69b1a3ab3b0b9af1859
# Peace
# 61882e8f1755e7fb4032d0f52ae2534d
# Cup
# 66121594f2c8330ef8b185c7d8cdc2f1
# Spain
# 9fd24726bdaaab7df2db43f6e12e9dae
# July
# 8b2a0e0ac94a6617030d8a24b1094fb5
# August
# 25f5971b164aac05a05e73d60b851dd6
# cities
# aeca6fc84a363300ed9846d0ae1e9912
# Madrid
# 4f56eee42529e5ead55b002565696d4c
# Seville
# a59cdf44c2f4d8d1bc44fad1de2f2566
# Málaga
# b98f57715529ff75a7ee9c228c7d6231
# Jerez
# eb1ac81d39651f891df556e7c571a6e5
# Huelva
# 18e5f1c5e2dd4477210b1a13311bb87b
# first
# 2d226866fe747338cf58f0e662061e2d
# time
# ca0bd8ed4c1acbfd06aeea76b5eb4355
# nation
# 5af3997da1b475b156282cdadd83e553
# South
# 296efd5dc13b18babd41c3c9c84376d0
# Korea
# 7c37e5e73ce77b398661476896392402
# winners
# 164aee192e4ec832547dd2f9793e4102
# tournament
# eac57c84699543964b09df1aedcf51bb
# Aston
# e3fae78be45a6c186e4751113040224e
# Villa
# b7929cf05d570a399a68c47efe2ef544
# Juventus
# 20095a888a5e7dcdfd1e62880eda4816
# Olympique
# 522da11896377e6feb4cf30274316f99
# Lyonnais
# 5a775e1339da3a8b8324018066ebbd13
# previous
# 7d688981a66eeadaee9eb047ec5fe8d4
# holders
# 87fe903cb9badbbcc12a3225650499ac
# tournament
# 4354ef601ffc130ad2448a209c357fe9
# edition
# fc4325c7c61f6fa779c94a68e5b0404a
# pre-season
# 94346088214978798cec4c439a359c50
# friendly
# 5602e287c07ad1bc2c6f932246bc21d8
# tournaments
# 31e5c141c2479268bcd7eaebfcdb20c1
# others
# 72fb16694beab246844cdf7721fbb2b3
# Emirates
# f6b3a03b7f5c4a9e1b465b80b8d85136
# Cup
# 7e5df253ddc65d23560e012328c9351a
# Barclays
# 99acb457d46e08897569efaf91a10f7f
# Asia
# 1c432cdc6ced1bc35c6d00f8b200ebf7
# Trophy
# 0ce8921828069fc9d7037ad0ffc4a5fc
# World
# 139e41d5049d3093415fdfec6227c200
# Football
# 6bee30738df3bfde41a47aafab961cd5
# Challenge
# 38a1ee9e91bf7225f389c2323704719c
# Wembley
# 2e3da63193a01189a1753ef6c01ba848
# Cup
# 7c458fa06485be2532b5c3790ec361c8
# Amsterdam
# 0cd74c4e34e908c73cb8d9a8d0ef73c8
# Tournament
# adef320e26e2c1d6cf2f4731d84f37b7
# Audi
# 49b6046db68e666e5f495e3ff387c7ba
# Cup
# d54df8e4ae351716ce28a2378177c75f
# 2016 Asia Cup
# The 2016 Asia Cup (also called the Micromax Asia Cup T20) was a Twenty20 International (T20I) cricket tournament that was held in Bangladesh from 24 February to 6 March 2016.
# ['The', '2016', 'Asia', 'Cup', '(', 'also', 'called', 'the', 'Micromax', 'Asia', 'Cup', 'T20', ')', 'was', 'a', 'Twenty20', 'International', '(', 'T20I', ')', 'cricket', 'tournament', 'that', 'was', 'held', 'in', 'Bangladesh', 'from', '24', 'February', 'to', '6', 'March', '2016', '.']
# It was the 13th edition of the Asia Cup, the fifth to be held in Bangladesh, and the first to be played using the T20I format.
# ['It', 'was', 'the', '13th', 'edition', 'of', 'the', 'Asia', 'Cup', ',', 'the', 'fifth', 'to', 'be', 'held', 'in', 'Bangladesh', ',', 'and', 'the', 'first', 'to', 'be', 'played', 'using', 'the', 'T20I', 'format', '.']
# Bangladesh hosted the tournament for the third consecutive time after 2012 and 2014.
# ['Bangladesh', 'hosted', 'the', 'tournament', 'for', 'the', 'third', 'consecutive', 'time', 'after', '2012', 'and', '2014', '.']
# Micromax was the main sponsor of the tournament after 2012.
# ['Micromax', 'was', 'the', 'main', 'sponsor', 'of', 'the', 'tournament', 'after', '2012', '.']
# Along with Bangladesh (the host) and Sri Lanka (the defending champions from the 2014 event), the tournament included India, Pakistan, and ICC associate member the United Arab Emirates, who qualified from a qualifier played from 19 to 22 February 2016.
# ['Along', 'with', 'Bangladesh', '(', 'the', 'host', ')', 'and', 'Sri', 'Lanka', '(', 'the', 'defending', 'champions', 'from', 'the', '2014', 'event', ')', ',', 'the', 'tournament', 'included', 'India', ',', 'Pakistan', ',', 'and', 'ICC', 'associate', 'member', 'the', 'United', 'Arab', 'Emirates', ',', 'who', 'qualified', 'from', 'a', 'qualifier', 'played', 'from', '19', 'to', '22', 'February', '2016', '.']
# India beat Bangladesh by 8 wickets in the final to win their sixth Asia Cup title and were unbeaten throughout the tournament.
# ['India', 'beat', 'Bangladesh', 'by', '8', 'wickets', 'in', 'the', 'final', 'to', 'win', 'their', 'sixth', 'Asia', 'Cup', 'title', 'and', 'were', 'unbeaten', 'throughout', 'the', 'tournament', '.']
# 69dae79b38421f1aa3423daa724a23a5
# Hold
# a8d4ff1d3284ec535e47b669bd4e4e04
# held
# c4aeee49f48997ec1b6377c7a3fc81ff
# Process_end
# 608e0687af2966ac11cc45a027d1b7ec
# final
# f76edb525f8d1768377a5679aca18110
# Name_conferral
# cda4a49211a5edb51fc81827651c10bc
# called
# 43e066b0571db81263065dd4ac897250
# Hold
# 2899649c2a5b304fb111e788206f9639
# held
# 819b89c8bad7f48beaa823570b6ea51d
# Social_event
# 44ea81a3e059cd92f0c0b8f85a3ace0f
# hosted
# b8deea6c5bc542dbe1f064d4f9e9b25a
# Competition
# 95de47e2dfd5b194edb166697dad5e30
# beat
# ee5dd8de529736e65b5989f4d6137b2e
# Competition
# 9e389d08bb8eb90c205cb9e2e06938e5
# tournament
# 3af78b4b29eb2267b45c3e2fd1634311
# Competition
# 6b74c141423cec92c5da823106a80be6
# tournament
# 6109810eb1f261326b6655de38d4dd61
# Competition
# 36eb847b7b5eb67e2142e558de2d78b5
# tournament
# 183875f4643c3acd3b288774039f360b
# Competition
# a1aeb59bc219b4391fde26915bd11b6c
# played
# 43ad910a0b8e2225977bec50f2cbe49f
# Competition
# 3a28cfc529f47137b264293af57798a9
# tournament
# cca0d5527bf38cd45bc7faab619eab26
# Social_event
# 8a8853edc41177e956717950240df298
# sponsor
# 22736c249872dd13af8858d3f59903c7
# Earnings_and_losses
# e192165da315a5b31e0510e0d2fa05f8
# qualified
# 89d833a7d81a0e9dd192affe8442c412
# Asia
# eb6b1ff3bdba0f665c5e055a5d00bc02
# Cup
# e0a6a785efc275385b55e4213a9eb602
# also
# 5b6a9eb4bcf6c6b54e88802bd2e85ea6
# Micromax
# 2e4794a399afb5543ec27f3d1ca4dea8
# Asia
# 1c0fc132d3e6d879c56fef7df7dd5f05
# Cup
# 59ea6a8bfa40dcedb9ecebb3afa7d9e2
# T20
# 8de64bbdfb21d0b2f0ab67d9ab830359
# Twenty20
# 45265d32da7eaad61f29934beac63783
# International
# d40148fb9c6aed2578e8c06b2a7e467a
# T20I
# 384a0d2b119954435889b388dd4457d9
# cricket
# 73637011bccefe3b83829c6a5cab1e97
# Bangladesh
# f517220dbafb572eb05551d95e3c4229
# February
# b9f743a120883328d21867143735461b
# March
# 4230a21009a0c24536407bf053ae4248
# 13th
# d2a6422fe912d52adc3fc10e079c5103
# edition
# 2509c6ee2960c8c7ac90453d1aa224b8
# Asia
# 5e41edc548434eba8d20a00be1f89900
# Cup
# f847d2b18a0bc77ed512d90bf1627414
# fifth
# 881d7ae2d0ef551821537da53ea07551
# Bangladesh
# 1954e46b6e774789197d0d00ab02ae88
# first
# 972a304b75a6a65d25d4d1c32b904978
# using
# cf87ac8fbb50ca3720b986254bae168b
# T20I
# 0bcf75052da4e8286dd0d99715c42049
# format
# 2aa63608db9b90b5b748a182f885f04f
# Bangladesh
# a3e30848bef31f2b9165056e9f997a37
# third
# 5d9ace4b0cf0e28e7a152287f0882632
# consecutive
# 72140a3db707bbe18f7e9402527d8716
# time
# a4a240e1496e2de88dade00d49f6fa61
# Micromax
# 2192d6a26076e4f5a7d1c115dcdc2bb9
# main
# d36885300ec9e4c0150c7eb8a0713646
# Bangladesh
# 5d5d4617bac04e56cce2b79501c0ff7a
# host
# d0afd800a767483c51d398a602a9b961
# Sri
# 40557fdecd3a28bba042add67cf5c508
# Lanka
# 94cc29b5efad1bce0c703739edcb1e0a
# champions
# f4aef34bf1d690fd321cb7c0cf6d9d16
# event
# d14ce58ce7cd42bac796c6403bd531cf
# included
# 323d4f72114bbf147acee498b08a5675
# India
# 89f1ecd569a45031d4aaa30f710abb8d
# Pakistan
# 0b522600171d937f29ffab1859241c1d
# ICC
# e60dd2a7bb1ea272f35545a9fd3c9ac5
# associate
# b2fd59af76c3e743ac2296376a6f38ac
# member
# c88ba9f0aaca3ff6cfd55765fcb53d4c
# United
# d8e6674cc5ef97b411f680c911b6df77
# Arab
# dfd7cd96cda1e7b5ddfdc7ae129d2468
# Emirates
# 906cb967957ed67b0793661ef6500c80
# qualifier
# 9ff31abaab730813bc05d52cd0d4deb7
# played
# beea14026db94f77abf2c41d0f8c6582
# February
# 726a6e40300c2996434085f6000dd804
# India
# 9b4bc5cca4ab606a7931265b1ec07490
# Bangladesh
# a43b268f6564b888b1d134ae45f558f3
# wickets
# 865704dc8823fadb9f1a979042b514a6
# win
# 4fdc072909a40808f5756a4f5649e467
# sixth
# 68057d29cd76f862e51c08b70ab49186
# Asia
# 4005323b02df3d9cde8584f23fb850c0
# Cup
# 1f38bfe5f581e7a48a9e939b4d96eaad
# title
# 02faeaf4654b6a5fc79b039bf9fbe67f
# unbeaten
# 79bc7cb3bd658e07fe0b80519ca511d6
# tournament
# 654ec6ffdf5bb78e24e13d3faea3b3f0
# 2014 International Champions Cup
# The 2014 International Champions Cup (or ICC) was a friendly association football tournament played in the United States and Canada.
# ['The', '2014', 'International', 'Champions', 'Cup', '(', 'or', 'ICC', ')', 'was', 'a', 'friendly', 'association', 'football', 'tournament', 'played', 'in', 'the', 'United', 'States', 'and', 'Canada', '.']
# It began on July 24 when Olympiacos defeated Milan 3–0 at BMO Field in Toronto, and ended on August 4 at Sun Life Stadium in Miami Gardens, Florida.
# ['It', 'began', 'on', 'July', '24', 'when', 'Olympiacos', 'defeated', 'Milan', '3–0', 'at', 'BMO', 'Field', 'in', 'Toronto', ',', 'and', 'ended', 'on', 'August', '4', 'at', 'Sun', 'Life', 'Stadium', 'in', 'Miami', 'Gardens', ',', 'Florida', '.']
# This tournament followed the 2013 edition and was staged throughout the United States, with one match held in Canada (Toronto).
# ['This', 'tournament', 'followed', 'the', '2013', 'edition', 'and', 'was', 'staged', 'throughout', 'the', 'United', 'States', ',', 'with', 'one', 'match', 'held', 'in', 'Canada', '(', 'Toronto', ')', '.']
# The participating teams were Liverpool, Manchester City and Manchester United of England; Milan, Inter Milan and Roma of Italy; Olympiacos of Greece; and defending champions Real Madrid of Spain.
# ['The', 'participating', 'teams', 'were', 'Liverpool', ',', 'Manchester', 'City', 'and', 'Manchester', 'United', 'of', 'England', ';', 'Milan', ',', 'Inter', 'Milan', 'and', 'Roma', 'of', 'Italy', ';', 'Olympiacos', 'of', 'Greece', ';', 'and', 'defending', 'champions', 'Real', 'Madrid', 'of', 'Spain', '.']
# Manchester United won the tournament, having beaten Liverpool 3–1 in the final.
# ['Manchester', 'United', 'won', 'the', 'tournament', ',', 'having', 'beaten', 'Liverpool', '3–1', 'in', 'the', 'final', '.']
# The group match between Real Madrid and Manchester United at Michigan Stadium had an attendance of 109,318, a record crowd for a soccer match in the United States.
# ['The', 'group', 'match', 'between', 'Real', 'Madrid', 'and', 'Manchester', 'United', 'at', 'Michigan', 'Stadium', 'had', 'an', 'attendance', 'of', '109,318', ',', 'a', 'record', 'crowd', 'for', 'a', 'soccer', 'match', 'in', 'the', 'United', 'States', '.']
# 5b2123ec06bb52b393f05ab533e98221
# Process_start
# 06985fc1a173d42c0d45f9e14005813a
# began
# 36ff2eaee44e1deb066e19f73a593c69
# Process_end
# ab653a369198c6a309fb2aebc2a67fcf
# ended
# 860ee9522e8409c0e4f2e77f60d1282b
# Competition
# 9867444e6faedfa0f3b3291de6b182ad
# tournament
# 3abb6c48135dd9f9dfb7d9625053724d
# Hold
# 4afdca87095e251bf075d1438864691d
# held
# d9fe8924189ec7e3ddab6e09ef000e32
# Participation
# 9035de37f65ede8dafc70b928bc7bb8d
# attendance
# 3f1e5765cc12673bfd30d8780a6ff9e9
# Social_event
# d3f0cce0365d18c76613ba6f052550bb
# staged
# 2173f34b2452f6fcdbdfa47dbb6fb7db
# Competition
# 567e3ce7784d1be2262dd4459ab4db78
# played
# f75d5827825a82ce4b83bb4789e7ae3f
# Process_end
# 0fd19776c8c1cdfc675812fa9fd5878d
# final
# c9a36b582e45523e2397bbfc3abcf09a
# Conquering
# da07f1835d9ff9bed6cc5a8c6b109480
# defeated
# 2e6670746ab3d488dc9b37135478bbea
# Competition
# 9369ff009712459cd32bba1116865c4a
# match
# 9689b957e25832a6b8dfc02110a69872
# Competition
# 3f8fec6e8830be3de3301fa5f6c10f98
# tournament
# 0538441033c9cdd70c2969a540446877
# Competition
# 3b8089e47e0598e3b7724f41d39531da
# beaten
# 93ff372a27b7d80c48f9f1c66436a206
# International
# 33704de675d974b8423cf83c8ed175c4
# Champions
# d73cf1de39158da6d8e846131df5c917
# Cup
# b1ca669bd87ad8506eef8ed00cafb1f2
# ICC
# 7232337678ed8e199dfa67f535b3d30c
# friendly
# 7491f716cde616c4b11547595931d90b
# association
# 4b86d688cf5c72813247aefe3eae8d19
# football
# 0b3e0e638a18e36f33e610d498525a41
# United
# 1c090c606abb4214ed14b5510573c1e2
# States
# 3902d90ea4749c1b0f826ea5fcc542cc
# Canada
# 8f77d9f7268ebd49d924e4cbaac00a5b
# July
# 38a6f4a32553df3fbeedd7d46d12ff68
# Olympiacos
# 18d5375f73f620b3864c87f2d73ad720
# Milan
# a765ab28d867d2a1c58c64314abddf24
# BMO
# e23a562592e76f7d6841a6fdc573dee2
# Field
# 3aa88af76590214688b64d2cbf323788
# Toronto
# e3358624b48dc0385fedb6547f67eb5c
# August
# d611c10bca02b457348a85b59e630c2f
# Sun
# d0bcdfac5e8d967bbab133efe0a15567
# Life
# 1058ccb741c8411e0ccf404ce32814da
# Stadium
# 26167fc752ab9578ebd9b29c450846a9
# Miami
# caa79bb684f8131d88dbe58c65b6dd20
# Gardens
# 3defd70bda93f5d73414d639223e30fe
# Florida
# 2e70e6a53d11d1f29de9e98caf750a7b
# followed
# 0e7ad2fe9c6133db5936213ea1e91308
# edition
# 3c1e5b2cde01acc461b2d5cd0771075a
# United
# e88d7b0a6d0bcacbeb1e5c6a4b699141
# States
# 2c2c7940718892bf187d820b4fcf0115
# match
# f89d5ac76408e0193e6f61e97c60b9c8
# Canada
# d28130e987ce45939e5200eaa12b0e6a
# Toronto
# 4c72e37a3144203763cb5cf356bfd1a2
# participating
# ae1a6206e35c4c0d8228726880e91226
# teams
# b0f56b5d6ef3d5e1afdc210f6f239803
# Liverpool
# 8e27728f454c1750cbdd00f161bd049e
# Manchester
# 98c44079ceec17ec43c8d8f51571efe8
# City
# 302cbb521f432d4f3cb061ba6d8b22db
# Manchester
# fdf17cdeeb6ce7cb1481b5bc3de07134
# United
# eb57e92a1d7df3d9e707308f3d8b73f2
# England
# 417dc4c1a1dfe16047a8c107617b137f
# Milan
# abd997a5ee55fbebb635393b60103477
# Inter
# 6c06cb8d1fc183ced913fd1f5d7ef2f8
# Milan
# 450afa3838f118960bb2628bc479b8ff
# Roma
# 30efe5b813bcc5ac5d0dc17afe93846d
# Italy
# 0dd462c647fb571f50fdca9ea4349e67
# Olympiacos
# 6a125d80aaf6037a8653b4ad2fd594b1
# Greece
# 20716cb96fe37769a02568fc9a9b6e6b
# defending
# a3a254bc10a0c08fb7ac191bdc8f59fe
# champions
# a44826d07c2754b23ab0230e63bcd108
# Real
# 901bd63f6d43b6a86b40698da43f2140
# Madrid
# 35d46a8d1924da5ff530167d03b534ee
# Spain
# d0ce39fb186b24e77dbb1a938f34a2be
# Manchester
# 7aa22993528a6f93d93fb2a09d795f1d
# United
# 230220814f8a7fe990b958569a9dd774
# tournament
# 13500ab72845711e968977ad9df01e6b
# Liverpool
# f1e1df291600e0de75131db4249fdc7e
# group
# 36637f31b72595c8f3c8bdf86acf32e7
# Real
# 71b992000d5d8c1bb76bc5da17f74757
# Madrid
# 9789c2ffd481e4d8a96ef8cde726c1e7
# Manchester
# 78759afdd19661fc6535ee67079b6658
# United
# 0a8a43c02b2114a9b6c6e6eb37eb4a53
# Michigan
# 88bf4538c4958abb8823895c5e582959
# Stadium
# b92ca480f644fa270e8775dcc3fa647c
# record
# e1176511108857ab5c7b31dd66c322f1
# crowd
# 3bfcb90c96d6a86bae974bac02f09902
# soccer
# 88fd70d2a378c4da5ffe42212eef7104
# match
# dc9a9c42c258b02675d8341d1dd46717
# United
# c1c49cf5db4076618fb72f61aa52030f
# States
# 0f761601f2bcc7c28628b3a646c6cbd0
# 1989 Southeast Asian Games
# The 1989 Southeast Asian Games, () officially known as the 15th Southeast Asian Games, was a multi-sport event held in Kuala Lumpur, Malaysia from 20 to 31 August 1989 with 25 sports featured in the games.
# ['The', '1989', 'Southeast', 'Asian', 'Games', ',', '(', ')', 'officially', 'known', 'as', 'the', '15th', 'Southeast', 'Asian', 'Games', ',', 'was', 'a', 'multi-sport', 'event', 'held', 'in', 'Kuala', 'Lumpur', ',', 'Malaysia', 'from', '20', 'to', '31', 'August', '1989', 'with', '25', 'sports', 'featured', 'in', 'the', 'games', '.']
# It was officially opened by 9th Yang di-Pertuan Agong, Sultan Azlan Shah.
# ['It', 'was', 'officially', 'opened', 'by', '9th', 'Yang', 'di-Pertuan', 'Agong', ',', 'Sultan', 'Azlan', 'Shah', '.']
# Although Cambodia did not participate, Laos returned to compete for the first time under the new federation name in this edition of the games.
# ['although', 'cambodia', 'did', 'not', 'participate', ',', 'laos', 'returned', 'to', 'compete', 'for', 'the', 'first', 'time', 'under', 'the', 'new', 'federation', 'name', 'in', 'this', 'edition', 'of', 'the', 'games', '.']
# A unified Vietnam first participated in the SEA Games in 1989 as well.
# ['A', 'unified', 'Vietnam', 'first', 'participated', 'in', 'the', 'SEA', 'Games', 'in', '1989', 'as', 'well', '.']
# The closing ceremony of this multi-sports events coincides with the 32nd anniversary of Malaysia's Independence.
# ['The', 'closing', 'ceremony', 'of', 'this', 'multi-sports', 'events', 'coincides', 'with', 'the', '32nd', 'anniversary', 'of', 'Malaysia', "'s", 'Independence', '.']
# This was the fourth time Malaysia host the games, and its first time since 1977.
# ['This', 'was', 'the', 'fourth', 'time', 'Malaysia', 'host', 'the', 'games', ',', 'and', 'its', 'first', 'time', 'since', '1977', '.']
# Malaysia previously also hosted the 1965 games and the 1971 games, when the Southeast Asian Games were known as the Southeast Asian Peninsular Games at those times.
# ['Malaysia', 'previously', 'also', 'hosted', 'the', '1965', 'games', 'and', 'the', '1971', 'games', ',', 'when', 'the', 'Southeast', 'Asian', 'Games', 'were', 'known', 'as', 'the', 'Southeast', 'Asian', 'Peninsular', 'Games', 'at', 'those', 'times', '.']
# The games was opened and closed by Sultan Azlan Shah, the King of Malaysia at the Stadium Merdeka.
# ['The', 'games', 'was', 'opened', 'and', 'closed', 'by', 'Sultan', 'Azlan', 'Shah', ',', 'the', 'King', 'of', 'Malaysia', 'at', 'the', 'Stadium', 'Merdeka', '.']
# The final medal tally was led by Indonesia, followed by host Malaysia and Thailand.
# ['The', 'final', 'medal', 'tally', 'was', 'led', 'by', 'Indonesia', ',', 'followed', 'by', 'host', 'Malaysia', 'and', 'Thailand', '.']
# 082ebc5264216807106f604162005e6b
# Participation
# 9eebc3bba49e24816bb1ee2a6cb5b02f
# participated
# c0b3994efcf79bcc1440231be06592a4
# Participation
# 1267c5719bf4757552eb866d94920a80
# participate
# fbda5a3b44dcb6237cc681e66eb780a9
# Competition
# 34b7aff668290eeca817142a71e82c79
# Games
# 24ac62fe27266627c3debe6bbe8e22bb
# Arriving
# 46961140b71b40b6f8436ea892fd0068
# returned
# d94451564e1f0d61b280f497ba96b608
# Process_end
# ce7e5e39aa05c4fd9413c0c9d524379f
# closed
# 52632ee0eff983c5b640c1f14055a69a
# Competition
# 7e1caea055606a0e4791c1045e283ee3
# compete
# 9b9aec7183f0ff09f2527becc348c13d
# Hold
# cc5611cdd9f41f9f3f86a0251fdd00a9
# held
# 360e90b302215fb9edb40af1205db0be
# Process_start
# 1077cb2a9db6336396328b0ab38610c4
# opened
# 0ffc7a7a05a1bbc152de097b9df59d78
# Social_event
# 50c19652cf3e61bcacce817b41234065
# host
# 253e9cfabb6893bca1e07ef91c297fab
# Social_event
# 96de43b7373efedc7ac7b462290fbca9
# hosted
# ceb1dae7d26406712ba98a20ce0f9117
# Process_start
# ef5c89a65f48a7db235054bd12b66aaa
# opened
# afd1531a499ae73928b2dc37f1c23086
# Competition
# e10fa4445e30f940eb2bf95a4d9331c0
# final
# ab31f4458c6537a8867bffd03bc00b40
# known
# 6600b85514acc3fee09bfe9cf5914038
# known
# 6d6f119fad9db7004bb2a5f3fe19b761
# featured
# b589392efb055de48131357b2a957a73
# Southeast
# e85e0ee8b235d803b988f585285c66ce
# Asian
# 7ea599f0755f5cdb0d87db5d16461fbd
# Games
# d4e1a1bc9810e4e4172db853f0f61f0a
# officially
# 7b5f0820ae219e8c4cfd711c1f57f919
# Southeast
# 73c416bb556ef5d65b5e113ea0d2e535
# Asian
# a9c01b3d50a054a2f95ed917bfc8624c
# multi-sport
# 25782e1d1013652aa2cd3f7cbe72f892
# event
# eec5a8c6e8619954d1dfb1841652c2eb
# Kuala
# 270dadf31df551d8a7b3b26b62794963
# Lumpur
# 0498fb3141b13518f5bd42d2aea527aa
# Malaysia
# 1aa1d3cfd2b55f4db0f42108e6f0d9fb
# August
# 2bff13fc3ac40703088a7efdfd384e0e
# sports
# e4b9fcfcd197737f37dd6b0dd62089a8
# games
# 712b84f51b6ab7746aa83aa9acb66daf
# officially
# 7c88a17b3fc4a9b2bf0fb6e6e64e97fa
# Yang
# c2f016f612b02a937bf128312fad584c
# di-Pertuan
# d783f756c97be3b81812f4d92203be98
# Agong
# 845b79b1272410d2d222d6bf661e1849
# Sultan
# e0e94e0144abd8c59ad04994b6df9bd7
# Azlan
# 250873daa5c99cecdb8d957fd0ed956e
# Shah
# 17316b43de7e67bb874904b3530a91ff
# cambodia
# 60d13899e93c277e2de99e5694836f2f
# laos
# e5f1a951b9c2afde4e5a4281da45b443
# first
# 440bef7db85e2b88af338b3145677a5b
# time
# f80639f28dccb960ae96ca88e1385ed8
# new
# 73b909db9b43df2a4a089d926c11681c
# federation
# 2efdc342afa513965f4676a436f4e7f7
# name
# e4549c04a59f9543deac0bd782aa4b7b
# edition
# e7c2cf608d6d15930958dee4a127ff07
# games
# b2d1a77ccd10ae5b1a955f4d6256210d
# unified
# af785a2cc3f75839f6a4800d80350ec3
# Vietnam
# cc236b24953572070c524f0ecd63946e
# first
# 18b6ad86268d0c700ff4f21a044a59bf
# SEA
# 4362185761a8b6644392899d8de7a230
# Games
# 42e1db5a5f960d605352b1ce129c8561
# well
# 3086fc831fc2ecd6fb91e6f08d12d541
# closing
# cdddc31d9272346a3d36acf9624c2c04
# ceremony
# 4bdb6163e071ff89312fdf55f124597e
# multi-sports
# a4f4e693942e1ba197e99ac186c8921c
# events
# 9507ec3ec05bceb9dec3e059eb84bcdb
# coincides
# 923eb6c890ebc836f4f8b02cac327e56
# anniversary
# 0ab739ea71a43b69b17f50dd5dcda997
# Malaysia
# f917d326bcd463ab551623e8e283439d
# Independence
# c1279bbf497efaea23ed2a402865908c
# fourth
# 9f34149e12bd2e88a629d11a6c0f85d7
# time
# be58f6f76323fbb2f0d9fa9fd949d9cb
# Malaysia
# a72bac23fa9bed0d5a4159881badbb11
# games
# 99d096a85c82225213b869f599987534
# first
# 4fe12ab0a0e0b213601a7c6be782d3da
# time
# cae1593df449dd8c1f9645f35631116c
# Malaysia
# 8a935c1df242a4025fa61e9c9e8b07d7
# previously
# 0b9610a20b7e678dd149fb75ed864aee
# also
# 87e1a7ff407623660a6c7daa32321db7
# games
# f86ece3bbc04470dbc557d7aea44f3e5
# games
# 1c353af75186370135984ec2b971a79d
# Southeast
# 69c09f706205c1c04184c6bacb8e9313
# Asian
# 109a948c2d2908d46a4492af8c2d2673
# Games
# 509045086c897732dc86082db4a01e6c
# Southeast
# 6083037b2a284123416234a2d51d44a3
# Asian
# f9197c1652dc55d419b295f7b8977da7
# Peninsular
# 70051926f0e6e49c7abefd6c1f6be453
# Games
# 5fee19d666818356474ed93b92f98c82
# times
# bad6f8c431769fdc7c8c74e836d192a3
# games
# ad9f354686f4ab9b0b1b818e233f5406
# Sultan
# 5abdde965e2753d87284dd8ec35f2ae3
# Azlan
# b1239fba7e30b0009a951e3acbc6add9
# Shah
# 6f1c35343734bbf64d155cb9df617902
# King
# 687408364612b376fcb227fbaef1e958
# Malaysia
# 6bcc9f90844b85add4263dbb2fe0f41f
# Stadium
# 7cd2372f17871293b09ee0c5d9baa7e9
# Merdeka
# 4cd2ed557e9823087660a68831b09baa
# medal
# fbc4d30ed5ea99a7f7df3e14590e5218
# tally
# f9970b9fef1c3d4ed4dd3136d9ec044f
# Indonesia
# 0cf6bd0f64f147c55263a63e0efe084f
# host
# 15f81c97427acca9978085e4ed689cbd
# Malaysia
# ac6d7fea502dafa1adb018d4eeb1f737
# Thailand
# 780c036d059ae05f3e3eab0635f226d9
# 2003 ASEAN Para Games
# The 2003 ASEAN Para Games, officially known as the 2nd ASEAN Para Games, was a Southeast Asian disabled multi-sport event held eight days after the 2003 Southeast Asian Games in Hanoi, Vietnam from 21 to 27 December 2003.
# ['The', '2003', 'ASEAN', 'Para', 'Games', ',', 'officially', 'known', 'as', 'the', '2nd', 'ASEAN', 'Para', 'Games', ',', 'was', 'a', 'Southeast', 'Asian', 'disabled', 'multi-sport', 'event', 'held', 'eight', 'days', 'after', 'the', '2003', 'Southeast', 'Asian', 'Games', 'in', 'Hanoi', ',', 'Vietnam', 'from', '21', 'to', '27', 'December', '2003', '.']
# This was the first time Vietnam hosted the ASEAN Para Games and the first time East Timor participated at the ASEAN Para Games.
# ['This', 'was', 'the', 'first', 'time', 'Vietnam', 'hosted', 'the', 'ASEAN', 'Para', 'Games', 'and', 'the', 'first', 'time', 'East', 'Timor', 'participated', 'at', 'the', 'ASEAN', 'Para', 'Games', '.']
# Vietnam is the second country to host the ASEAN Para Games after Malaysia.
# ['Vietnam', 'is', 'the', 'second', 'country', 'to', 'host', 'the', 'ASEAN', 'Para', 'Games', 'after', 'Malaysia', '.']
# Around 740 athletes from 11 participating nations participated at the games, which featured 287 events in 5 sports.
# ['Around', '740', 'athletes', 'from', '11', 'participating', 'nations', 'participated', 'at', 'the', 'games', ',', 'which', 'featured', '287', 'events', 'in', '5', 'sports', '.']
# The games was opened by Pham Gia Khiem, the Deputy Prime Minister of Vietnam at the My Dinh National Stadium.
# ['The', 'games', 'was', 'opened', 'by', 'Pham', 'Gia', 'Khiem', ',', 'the', 'Deputy', 'Prime', 'Minister', 'of', 'Vietnam', 'at', 'the', 'My', 'Dinh', 'National', 'Stadium', '.']
# The final medal tally was led by Thailand, followed by host Vietnam and Malaysia.
# ['The', 'final', 'medal', 'tally', 'was', 'led', 'by', 'Thailand', ',', 'followed', 'by', 'host', 'Vietnam', 'and', 'Malaysia', '.']
# Several Games and National records were broken during the games.
# ['Several', 'Games', 'and', 'National', 'records', 'were', 'broken', 'during', 'the', 'games', '.']
# The games were deemed generally successful, with the rising standards of disabled sports competition amongst the Southeast Asian nations.
# ['The', 'games', 'were', 'deemed', 'generally', 'successful', ',', 'with', 'the', 'rising', 'standards', 'of', 'disabled', 'sports', 'competition', 'amongst', 'the', 'Southeast', 'Asian', 'nations', '.']
# d8578a75a123b4c7f3965d461c35ebab
# Hold
# 38400559a6ca40192727fac2b7691c8a
# held
# 102eaa81e05110c978a4deefc01335dd
# Participation
# 83d3a1cac1711501b9d20921dadb1183
# participated
# a0330fab4b3054c54bd294059a90b3e8
# Participation
# ab0b166c9f285fd060b762c10ba0e6bb
# participated
# 78d0efdc275f5406261ef8588a7169df
# Competition
# c276f9a4c1e0029f0b39edf057fb4b37
# competition
# 675d566692a111240334c1fc124a1df7
# Competition
# 40c26eff416ad2aa3dec0bb4a9888c06
# Games
# 9f7f2cf8c9b47d35ee415d2a8aed42d5
# games
# acbec34a0ab4347e0faf5aec3302e46c
# games
# 6572835920075c7e8528cd836c71aeab
# Competition
# d798a1bf759fb475321c4769a1202c7b
# Games
# 516b7892ebc7279f54af7daa14a966b4
# Competition
# 38d03f36e44db87e9033c563066cbe3b
# Games
# 230c7f3f51ac4227db0a1d2e2da9dff8
# Social_event
# 7f6bca3e1e18c29a9cbc44842d14b140
# hosted
# e41a9fc26e03ac9c74cf8257b7767c2b
# Social_event
# 4446435bb8b7c0110b1eac362577af2a
# host
# 1d2449e4c47aa9a4903045eba6a7e466
# Process_start
# ddfb828d66f6ff5df5b2e06ce5a3c0ed
# opened
# e0d1c5d89426f7ddca214a55ac555472
# Competition
# f75fa53abba05543a5195f00c50085b1
# Games
# b4f09ab847612081ce8eb831645ede64
# Competition
# a6122f764cd5c6285ad08e498bc9e352
# Games
# d976b57ff32789487a0283a222cbdfe6
# Competition
# e37c5029d34a6e4eba6108996100f671
# Games
# e10045205341068236304a25548e79c5
# Competition
# 75162a20b84ed12a498eb5b508c61910
# games
# 5dbe9b1cb260f3811064c1c1b5699634
# Competition
# 26e701002e575a018e6cff76089a2df8
# games
# 5eedd298953679a1338f40161138aaf8
# Competition
# 0c7a9b4b3d5132e7bc4298062225809d
# events
# 3389d4678955ceb3d6b61370e60990dd
# Causation
# 742a34513883256bdc477be56ca1ece9
# followed
# e100b56cb1e8975f8ebf6f3180b35afd
# Getting
# 775e76abde0d666c1de1185980cdb996
# led
# 81a055a69594836e7c65f0abfd1e7a22
# Destroying
# a9f1b617ad87fbc34b971087cce3450c
# broken
# 9630ac40e0239f91a3acec9276cd6c1f
# Process_end
# 608261744bc8d311e03632b23db57172
# final
# f775dbd99fe79a599811c08208f4dbfc
# featured
# 48787a1406289a3141c14e0be14795c5
# ASEAN
# 8753b9f6330f019df9f078cdf1971275
# Para
# ca88896eb9d58f66ea2fc7e3f9da1923
# officially
# e0083475423b08e80dad8b00bcbdaf5a
# known
# 076a39c03d4751cc64247b60fd85d679
# ASEAN
# a17696e9f65d8b9ace7123e6e9c41dd0
# Para
# 4d120caa1674dfef5e27561ebd32756b
# Southeast
# 6c7d7c0719204371101e1b25f92e12e7
# Asian
# 0ecf1ef132b1bc38bc62bc188f0a4c3b
# disabled
# 6e664023de7955742b862b1d5a6154e6
# multi-sport
# d72d9d5dd95232e277892e29d263775e
# event
# aaec6f544bee15948dea72985fc889a6
# days
# ad54c774980df7cab8e6b8e17966778a
# Southeast
# 5fa6ea9a0ce440746be815dd1c0a7fa2
# Asian
# b922cbc959eee7f3ccaa404e22d4f5a0
# Hanoi
# 80d314c79421d3bbfd383a2191b82276
# Vietnam
# ce37d5f0d7f46c0772173207ce8a72ad
# December
# 85f5320b05b3e400e12b4b02a2b28ea3
# first
# 7d62f2885d790b1eb30b04ba670b672b
# time
# d53fa2119f8ce499777507aaa7b68390
# Vietnam
# 50fd6b4bd2bc18651528db6d17eeeb6c
# ASEAN
# 95ce7ee571d9e08e60122cf446fcdf49
# Para
# e3c47a22ad2959fe9178095a37810927
# first
# 9a8442c20b61002e3bd34c037e3944c8
# time
# 4ace337457761652a9b51c8c6c75b54c
# East
# 3b404031389b7f3351fd32cc7bd3dc5d
# Timor
# 31beea84d4eba77f34a285948346e842
# ASEAN
# 3d373f1f81c726793ff4adc2f9354d45
# Para
# 74776c9276be131cae175e146b7e1650
# Vietnam
# 272333940fe0816561084d61d3656511
# second
# 0d51539ff672f483a5ad0b3bd9fc0858
# country
# 7fc36241d858345d3798b3515f3acc91
# ASEAN
# c31347457442d36517cc3650bcc3ae9b
# Para
# 35165435081f536829bb687f00400c59
# Malaysia
# bbc68a9c9cbafeb515f4f9f51300fef3
# athletes
# 39b1ece9db0b7a56f95df5f1d39cc3ab
# participating
# 2d8b24e46da65d29a04fb1494bd083d5
# nations
# 5f139c54d3649c2543a6b579fedb3482
# sports
# 77e9d82bd4f56fba22786169411431bc
# Pham
# 5bc6eee3e12e83308f1c69232ae771f1
# Gia
# 723b3060b6536768daadc8a046384af4
# Khiem
# a6faa87d52df6bf0580d111e0742ca87
# Deputy
# d44f765b4b8c5514ffb6c4272fa79917
# Prime
# d3389e11c29e3e8d5ef30ed5873c05cb
# Minister
# d1d69340d12194947c5d38ade2055a16
# Vietnam
# 72fd28ea444c0e5bcab5656c3d8d24ef
# My
# 473d9ba150d05ae080cd4a0a42cccfaa
# Dinh
# ed321d00d2dc2b0b552ac22665988ebe
# National
# 68f3e327dd644d3acaedeac4b3b740a7
# Stadium
# f63ba6a06834a85ce0a00b874febde24
# medal
# f10e299e722a65efd76f60e3b4c74e2b
# tally
# 7d7808c387a2bdc1bda46844aac06b0c
# Thailand
# 95d4d2ed6f7a83de299934cb770e3f8f
# host
# 8170922c2bc30d08f4000c5e4a27114e
# Vietnam
# 9478adab8620091704647b5890288542
# Malaysia
# 08f6aa9e8d29ed47739fbb78d2bcc14d
# Several
# 750a7d16104e91dd6578fa1ab9827e15
# Games
# 29e7be57770c39cd49a1cadbe786342b
# National
# bac25c4eb2ac3c1c5df824759f0cfa3b
# records
# 9dc82287a89f1f707c182dfb4ff67be1
# deemed
# 31f12dcb7d78ca1752d571c201bd36f0
# generally
# bd438240cc2a9495108baff4b3109439
# successful
# 62cc9f12c75f4058bafb9d0fc13d4526
# rising
# 581505988b65244ca3424760902ce4ad
# standards
# ae14d62e4ef4642ba24c45c8ae8002e1
# disabled
# d7992cf8bef3bb4f617b8b4be741c3e9
# sports
# 526dac9e786a8d329a3dd4f1d9ef154f
# Southeast
# 949143a668a612ee23272686c036d0f3
# Asian
# 2466147d72a527045510b5fe84fad169
# nations
# a558c8f9a30c86aadc0f44eaef3d37d8
# 2014 Women's Hockey World Cup
# The 2014 Women's Hockey World Cup was the 13th edition of the Women's Hockey World Cup field hockey tournament.
# ['The', '2014', 'Women', "'s", 'Hockey', 'World', 'Cup', 'was', 'the', '13th', 'edition', 'of', 'the', 'Women', "'s", 'Hockey', 'World', 'Cup', 'field', 'hockey', 'tournament', '.']
# It was held from 31 May to 14 June 2014 at the Kyocera Stadion in The Hague, Netherlands.
# ...
# d32bca2acd73746600976053785829c1
# Becoming
# 57ec3dedb8ecf5390fb94e4e899ebb16
# became
# 73f9e08ea054962adf4f5657c8ad7461
# Attack
# c66015a0b7433d6c84876b4c141af22e
# ambush
# 7599a28d36221566de92d89ebb958212
# ambush
# 7179f7ac3e5fa0456a92126cb7d34084
# attacks
# 75b95b84f0af02ac63a210409fcfd7fd
# Process_start
# 2b16ff7d3c93b0c1090bfb3878f5f245
# took place
# d7acef0d28c1062b73eec6a11ec44967
# Name_conferral
# b0597deec93f22ffe1fe398a0beaa234
# dubbed
# d17afb39547c4eab0eb7a5380e379261
# Attack
# 818d29a5969ebc27691ba76f96b22895
# carried out
# fb8183bdd172b1e3875cc384e9ae5587
# Killing
# 941b90680bfd9710dc5add995bee21eb
# killed
# b7d9bfda72c1adefaef65f4fdfae5b7c
# Attack
# 666d1c4ae968cebb769deba4a2f40760
# attack
# 4519f11d6e7a34507c433a05cf9eae87
# Attack
# 77ca14429f3802f45c24b3fc46c9dc42
# battle
# 2bcb5576f3744bec01bcb24a741f5157
# including
# 7c981308a8ddb72eb41e6cbe3e1963be
# Hebron
# 8e1244ea7ff7be837ee7ea285059ef47
# Wadi
# 50c77d05f3ddb158ca62b4d4d161796f
# an-Nasara
# df93b685b9c5b9f52c9b7d94a306a5cb
# neighborhood
# af94d89835ed7a4a353635d92ae25dcd
# Hebron
# c40e0ccff8f30bcd767cdc0e8cbea221
# West
# 721f1478350e8142695f08f534048bcc
# Bank
# 5fb8d95381eb6985d256f9f48d5bb645
# November
# 4f2483638561542e069bd1cb683cc8bf
# Israeli
# 13e8f1757c0b4bcfa3214dcbfd4b4cf9
# forces
# 6c80dcc70d8ca87501ee9a4c9c91a297
# double
# 675bcfad1b701e82a91ca8b9cea8c03f
# militants
# fb0cd8fde9900942c6b9ab2b1172136f
# Palestinian
# 6e57750ed00e3ff7fee886a6cc0e8525
# Islamic
# 6b72ab0288732069dab39fa4995859e3
# Jihad
# 023dc6f241a41ed3d100238594c0d5f0
# battle
# ad94f18104e53fc2926b0fbf364cd9f7
# referred
# 1a70b20f716b11bbdf627b87c71c7411
# Israel
# 6b6793a29ba872e7775daaef53317e73
# attack
# 98ce7c6f37e3f020d84f9a39bf669a59
# worshipers
# 1e439b185250e6a552c7c41a7c29ce47
# route
# 35ca6c24663eb43275a1c41a1e9f51d2
# place
# be9a641c8c73e429f2af25cd592792cf
# attack
# ed451ff8af0e55d58ef50042d46217ec
# took
# f7710f4c4a5eccf14a5be73f24a3b782
# place
# c19f5431a6bdf4e1f3719f3f03268f8c
# known
# f7ede342febf626f848c0a34e78bc25d
# Alley
# c6e98dc0c290b17c012f0f413af3e261
# Death
# c4de155cc5867ac61fc7ac731a3e4772
# Hebrew
# 281f366120e8a3d1fe58a63dbf919ee4
# Arabic
# 80db4b52081eca75ff03c8fd474eeb6f
# initially
# 398eb1262f83a50911648ad64b8c0668
# Sabbath
# 8593fedec1f13b0b8306990528a11ce2
# massacre
# 4bb099c6b6b3d15bfc999579ce0a6d4c
# official
# 2d8857f3680558627366dd3b21c4e060
# Israeli
# 449450b4f7bb23c75a0da91bff8886ac
# spokespersons
# 7cb7625192676296e47c77f65b1d7ed7
# narrow
# dc2cecce4453c828a64525261c93cddf
# alley
# 7c741fcd9b3e5136ebdcfde25ab3e455
# passage
# 6c6e925faa98fb01c330626237ee6716
# south
# e7d198e158f47cccba6ce748601c3b8a
# gate
# a6e5fc05f4ac4bbeb033b1661d30394f
# Kiryat
# cc9a933d00d234fe29c58e75154f5b88
# Arba
# 82733a3a38d33bfe89ba32da97270c09
# Tomb
# 7ede064a2b766a935343932d957c1f66
# Patriarchs
# 2612c28d80c1a55a1e60b56411642cd7
# Palestinian
# 1a35a0ecc273c4463c5b8f3a60bdac73
# attackers
# bbab76cbf7004712d6516c9f1f3e894d
# Twelve
# f559ee6d25a0773f0b481c3e9a617f27
# Israeli
# 57cf8e4ef8deae49c0c23ab7dd5e1f5a
# soldiers
# 3acce2fa04e4442ac624e082a9b0d3f3
# gendarmes
# 36e454237c71ce86e2b4f0b452d586a2
# civilian
# 93c95c7a06cca20252d05f60268bc517
# security
# 6a74dc514dd30dc83eb8fd63cb640d7f
# guards
# 3391449e02ed09908593df3de7a2f305
# high-ranking
# 6c7825f8bc8780d2caac7b3fd923e709
# officers
# 9a1d90f0bd7654e97d6a9890659aa92b
# Palestinian
# 7414da327093ee173ea9b30f1b587ac4
# attackers
# ac554419cb34a00b44909dc8f1a23c8c
# Minneapolis general strike of 1934
# The Minneapolis general strike of 1934 grew out of a strike by Teamsters against most of the trucking companies operating in Minneapolis, the major distribution center for the Upper Midwest.
# ['The', 'Minneapolis', 'general', 'strike', 'of', '1934', 'grew', 'out', 'of', 'a', 'strike', 'by', 'Teamsters', 'against', 'most', 'of', 'the', 'trucking', 'companies', 'operating', 'in', 'Minneapolis', ',', 'the', 'major', 'distribution', 'center', 'for', 'the', 'Upper', 'Midwest', '.']
# The strike began on May 16, 1934 in the Market District (the modern day Warehouse District).
# ['The', 'strike', 'began', 'on', 'May', '16', ',', '1934', 'in', 'the', 'Market', 'District', '(', 'the', 'modern', 'day', 'Warehouse', 'District', ')', '.']
# The worst single day was  Friday, July 20, called "Bloody Friday", when police shot at strikers in a downtown truck battle, killing two and injuring 67.
# ['The', 'worst', 'single', 'day', 'was', 'Friday', ',', 'July', '20', ',', 'called', '``', 'Bloody', 'Friday', "''", ',', 'when', 'police', 'shot', 'at', 'strikers', 'in', 'a', 'downtown', 'truck', 'battle', ',', 'killing', 'two', 'and', 'injuring', '67', '.']
# Ensuing violence lasted periodically throughout the summer.
# ['Ensuing', 'violence', 'lasted', 'periodically', 'throughout', 'the', 'summer', '.']
# The strike was formally ended on August 22.
# ['The', 'strike', 'was', 'formally', 'ended', 'on', 'August', '22', '.']
# With a coalition formed by local leaders associated with the Trotskyist Communist League of America, a group that later founded the Socialist Workers Party (United States), the strike paved the way for the organization of over-the-road drivers and the growth of the Teamsters labor union.
# ['with', 'a', 'coalition', 'formed', 'by', 'local', 'leaders', 'associated', 'with', 'the', 'trotskyist', 'communist', 'league', 'of', 'america', ',', 'a', 'group', 'that', 'later', 'founded', 'the', 'socialist', 'workers', 'party', '(', 'united', 'states', ')', ',', 'the', 'strike', 'paved', 'the', 'way', 'for', 'the', 'organization', 'of', 'over-the-road', 'drivers', 'and', 'the', 'growth', 'of', 'the', 'teamsters', 'labor', 'union', '.']
# This strike, along with the 1934 West Coast Longshore Strike and the 1934 Toledo Auto-Lite Strike led by the American Workers Party, were also important catalysts for the rise of industrial unionism in the 1930s, much of which was organized through the Congress of Industrial Organizations.
# ['this', 'strike', ',', 'along', 'with', 'the', '1934', 'west', 'coast', 'longshore', 'strike', 'and', 'the', '1934', 'toledo', 'auto-lite', 'strike', 'led', 'by', 'the', 'american', 'workers', 'party', ',', 'were', 'also', 'important', 'catalysts', 'for', 'the', 'rise', 'of', 'industrial', 'unionism', 'in', 'the', '1930s', ',', 'much', 'of', 'which', 'was', 'organized', 'through', 'the', 'congress', 'of', 'industrial', 'organizations', '.']
# ab8edf451d92768ef94eaf555fa7d97a
# Process_start
# aa2d5b20097fe13e0c744aa54dbd512d
# began
# 1dec06beea094246cdd508318592a9b9
# Process_end
# 287e095e65524c756ca16ef34c34b76d
# ended
# 94eca63aaa98168e9daed1d13ec1d9d1
# Causation
# 97d937fe8cae06f26c6d8dc9ebe4d530
# grew
# 0cd8339856c0b334a2a73b00bff3475c
# Cause_change_of_position_on_a_scale
# 6cd02d104edd25d68bc554c95a5d5130
# paved
# 67da797777254ec2472ebd07a571a7cc
# Minneapolis
# 82e6fc15fd2cf0da68c5875c425d10aa
# general
# 35d772e76b964ddab592173a30c75888
# strike
# 2d5069f8afad30ef7f532cad2b5d2929
# strike
# fdf2b5302c5275e369097a38c98cc5d9
# Teamsters
# 042d6759e3a5ea5978a8366c7bc87510
# trucking
# 87d21dafd1fa73f6ecc42fe0957aed3a
# companies
# f6a3d479f279335c5a0aead00e7c8a49
# operating
# 42b78de39fcc3a827edccbab45f939f9
# Minneapolis
# 7ccfc3917d4508676bb61732fb29637e
# major
# 6240fb7bad958fce1b2e0afa372f6bad
# distribution
# 466abb295e9432aedc16207cdeeb52a0
# center
# 11d3aab3121e6ff397b62675394399ee
# Upper
# a48e06b435bfe05acfeb5a0dd7a5e57b
# Midwest
# 37cf1ba0781881c50dd60264d0f2e473
# strike
# 57b9cf43c7b9e99efc6822a216357294
# May
# c3deace8d2999fa3dc2c07beab0cf6ed
# Market
# f376c389919cd6fde81bbd20cd621a60
# District
# 44459b9200e8e8936c1334ff21972be4
# modern
# e2490786d483397ac0c459dd691368c4
# day
# 3b5d3d1ba6116a49e89ce5b759a8342c
# Warehouse
# 2150461a3259fa2cd6b3484217e5063a
# District
# 4bb6d8782c1b1cecc66d05bba642b7b8
# worst
# 0f8189764f4fd0fc7aa23db747b1aafc
# single
# d7f165572035647256d4e9c640ee1af5
# day
# 1f76d3b65c6b7efdac5fa18943ea8a21
# Friday
# 021225a6363baee13005e6fc0693b298
# July
# b071b51045b4e77a9e5e4e1d25b4e25c
# called
# c4d5ba1f4460c7e2805317134750872b
# Bloody
# 9ee1362f8f691b9403e8a27c51637cda
# Friday
# e29e4a19d9208e637e8c1e3823ed6548
# police
# 33595c40ac49a838aa548e2f2fde0ee7
# shot
# 205d9e77c63e4bae3922e385f4906cd7
# strikers
# e9badeb5fa1313cda09102417e9e72f8
# downtown
# 9107b8ca8e55823ea884e7a1e63c295e
# truck
# 20b2b73e9e952be9738a3ef7079e1ff0
# battle
# 99e75cbf664de76441adac4b0a7171a8
# killing
# 417df73bdb5560d2cbada507b280dd1b
# injuring
# 6eed5fa59d7d89a2da195704380f9340
# Ensuing
# 8b03761550e94275e0a553d020adbc46
# violence
# b8ec9ecbfc8665a46a28859596ce97e0
# periodically
# ca63c13ed159f4d1b36a2ddaa9df086a
# summer
# 975182df9448ca2590afbe1ed29cd61f
# strike
# b2202c4f3545aafdd9ee03888f4c3540
# formally
# 91f65854736cc66b2c25a0899d96a3b9
# August
# 5cfbe77b425a61e31b5c78c20ea8cc98
# coalition
# 0a3e5e2644aade68fae5c1daba834f23
# formed
# 62324a734dd0393806f14957e14ebdcb
# local
# fd31e6c14ed2c12eea182dd0e6083940
# leaders
# e6704d8ec62d28092962bbbb5ce2f74b
# associated
# e93e9b35926c14e653f6db05567700db
# trotskyist
# f0a5a6b92c75983ead9d4a779ae99570
# communist
# d295f6286d26f9f212fa2e1f4f3b00c0
# league
# e8ad9837c107f6d46c66885facd7e4c1
# america
# 4c9e7a5756443940d6dcfbf1f0c4b4b0
# group
# f8fa0dc1221c29214620b6135586fe80
# later
# 263aa6640e6819d9a3723682520e29f6
# founded
# 1caab9070199db2eb357d5a2a419a006
# socialist
# d7a51d7bd1176036dce545f3acd7abeb
# workers
# f2a0de9802ed1c8f901a1fd3b0d6c8cd
# party
# 8cd4c4592dab5fbdac61b70700c34f88
# united
# 760c45bc151996b5836da2faf5df4672
# states
# 7522b7dfaec628ba637a713675afc72d
# strike
# 21907654ffc823bfeb01790c7d1f3e49
# way
# 27afb495874fab9b5de572d9ddef6e8f
# organization
# 29bcb86fa4517b10a34f2b551d9ac96f
# over-the-road
# 2c8cba189f50408408e2aee53c396561
# drivers
# 7a37d51020b6f3f282a458a22ef16487
# growth
# 44c6a1590d2978155dfa3c874be76b77
# teamsters
# 941e2233252df728e3f5914b505d3bf5
# labor
# c93d3cc9438f0ce9b5ca6a9e54f36999
# union
# 17f3272a1526e0f085e529e6011214cc
# strike
# f224e2c9b1b85425b6433bdc9aa20586
# west
# 78c6ca07da8eb18bf3f55bec7dc8ffd8
# coast
# 38996e15b27901fdd8ded52d41d579c6
# longshore
# 2ff37bf1c9bdb99ad7c79d5f02dec3a2
# strike
# a307d41c3d8ecfa2cd75669fb079238d
# toledo
# df1d08d81b01aa9759f9a161d14fc68e
# auto-lite
# 197ee64a301a195583f71ae72584256f
# strike
# 86b29b0d80b2028dbddb941ee48d26e6
# led
# 077e04c975d8ea1d0988876ecf3c5ad9
# american
# fdc84fc16df005b3d0c6f3f7d70e657a
# workers
# 27900554ee3c9260620f78e91e67bc8e
# party
# 9225e8091fcb7396e5699ddd83d3b119
# also
# 46c813f4ef07dc1619c352a60f59a5ce
# important
# 5500d8cf578f7d96f1ee65f0e1ae664d
# catalysts
# 26c1d18e0192db1e497c7df8eb4a61f2
# rise
# 3de21147f7b664907804346a0f944700
# industrial
# 0e7d04f59bb2e15e77d20b9a918aeb0d
# unionism
# c15b423b2b6186a9226f8f89c574ca0c
# much
# 5e1fb7f924364760dc4a9c6f47991d20
# organized
# 0a377066787f0343b789385571e51253
# congress
# ee60301b33667b557e472bdec4c87852
# industrial
# f28baa240c081e4df53316b27c8045e7
# organizations
# 2f69f8d37a487b51b45fa7dcdc81973f
# Spanair Flight 5022
# Spanair Flight 5022 (JK5022) was a scheduled domestic passenger flight from Barcelona–El Prat Airport to Gran Canaria Airport, Spain, via Madrid–Barajas Airport that crashed just after take-off from runway 36L at Madrid Airport at 14:24 CEST (12:24 UTC) on 20 August 2008.
# ['Spanair', 'Flight', '5022', '(', 'JK5022', ')', 'was', 'a', 'scheduled', 'domestic', 'passenger', 'flight', 'from', 'Barcelona–El', 'Prat', 'Airport', 'to', 'Gran', 'Canaria', 'Airport', ',', 'Spain', ',', 'via', 'Madrid–Barajas', 'Airport', 'that', 'crashed', 'just', 'after', 'take-off', 'from', 'runway', '36L', 'at', 'Madrid', 'Airport', 'at', '14:24', 'CEST', '(', '12:24', 'UTC', ')', 'on', '20', 'August', '2008', '.']
# The aircraft was a McDonnell Douglas MD-82, registration Of the 172 passengers and crew on board, 154 died and 18 survived.
# ['The', 'aircraft', 'was', 'a', 'McDonnell', 'Douglas', 'MD-82', ',', 'registration', 'Of', 'the', '172', 'passengers', 'and', 'crew', 'on', 'board', ',', '154', 'died', 'and', '18', 'survived', '.']
# It was the only fatal accident for Spanair (part of the SAS Group) in the 25-year history of the company, and the 14th fatal accident and 24th hull loss involving McDonnell Douglas MD-80 series aircraft.
# ['It', 'was', 'the', 'only', 'fatal', 'accident', 'for', 'Spanair', '(', 'part', 'of', 'the', 'SAS', 'Group', ')', 'in', 'the', '25-year', 'history', 'of', 'the', 'company', ',', 'and', 'the', '14th', 'fatal', 'accident', 'and', '24th', 'hull', 'loss', 'involving', 'McDonnell', 'Douglas', 'MD-80', 'series', 'aircraft', '.']
# It was Spain's deadliest accident since the 1983 crash of Avianca Flight 011.
# ['It', 'was', 'Spain', "'s", 'deadliest', 'accident', 'since', 'the', '1983', 'crash', 'of', 'Avianca', 'Flight', '011', '.']
# The accident further worsened Spanair's already negative image at the time and exacerbated its financial difficulties.
# ['The', 'accident', 'further', 'worsened', 'Spanair', "'s", 'already', 'negative', 'image', 'at', 'the', 'time', 'and', 'exacerbated', 'its', 'financial', 'difficulties', '.']
# Spanair subsequently ceased operations on 27 January 2012.
# ['Spanair', 'subsequently', 'ceased', 'operations', 'on', '27', 'January', '2012', '.']
# 7204ac22f470600c281b3236ca2573b2
# Catastrophe
# 2a56aebc95ed9109cbc4926f7cf02ced
# crashed
# 110dbdcf973d5dd63372560fbad9102c
# Death
# bf50229ee3e7abd2964546b732eecbf5
# died
# 156aa6ea302014b38934480bf20a8aea
# Process_end
# 60493d779a950aca1796513ce330e23b
# ceased
# 9fb94b05a0ccdbbb9e97c764a5aa01f1
# Catastrophe
# d5b0dae2a8519ba316b711a381af5c13
# crash
# 59a5be983b759e237742b87cbf090bb5
# Self_motion
# 11ce58bf2fd6280b94f599d64c61d1a9
# take-off
# 2bcddd9421f54147352292d08c07f997
# Cause_to_be_included
# 76c1d046db5489ef47baaa0cb6189777
# involving
# 9034318c821a117c7abec1680077162c
# Cause_change_of_position_on_a_scale
# 7a8873803660c2b14b862788998c2721
# worsened
# 162f0777ecb13917337159f9d93308f1
# scheduled
# fb3e974b865049f75a6bdd030b75f4ce
# Spanair
# 88f88d211adf468f8bd8ff5a01e93ef2
# Flight
# 2ad6d65118462c717d05196c992a5c7e
# JK5022
# aa7b9db83f6254cffd7c8e8acc17a735
# domestic
# af6606b14d7a24f1968961a9364a95e1
# passenger
# e2a4ad9d1b4cd3959cfe5a4b7908ee86
# flight
# 041e311aa377d07d7718688d69adce58
# Barcelona–El
# b827d4e77adb9811505ca392aba327e9
# Prat
# 795f219ca5227ff721d5d0e136c4d928
# Airport
# daade10a7d9f54668e3a5442e76d50e5
# Gran
# 45a8e6fe0a492b4fb28069942774d7c3
# Canaria
# d3f8e4487ac3666db4440af1c07267ef
# Airport
# cf8fb7d99004f3a7c8066dad843fea5b
# Spain
# 7c33751b8e6d041a45672a37552a95ec
# Madrid–Barajas
# 556a4e77fcf03ae16db5733d2293209d
# Airport
# 2c896ea19a3d3abc1a7cefc6e6dde635
# runway
# 72812a535413e9cd7de9a64e361e64cb
# Madrid
# b1a430a6e7f2dfa9e005303fd6e30f73
# Airport
# 7d42a12934672628a96e87bcc3014e7a
# CEST
# 1ea8e13d6d8c418504a2f4e3553d1192
# UTC
# 76cda7c5df431b30b63948f855acd0cb
# August
# 984af331e457fbf2f070ddd8ebb9b865
# aircraft
# 44212b4c9b6e4d578e51d5c943bfe081
# McDonnell
# efc9c2f7b11d0b5e5984c6e56aabe9af
# Douglas
# 91158698c040d499a521372d4c2de5dd
# MD-82
# e9e3bf835674b8de6e2bf951d0dbb866
# registration
# 40f7266d0bea981097d63313ac84d2a1
# passengers
# 1243b8bc71ea67879e8477af1ea72845
# crew
# 3ee2c83caf8049e658b88e6aeae284b3
# board
# 683087553c2fba0d94734e2aa0813a0a
# fatal
# 1e3d4858f73d2ad2534d0ec38eeebdce
# accident
# 6d1c51bdc60d879dfcde46494612fdbc
# Spanair
# e18b52cec1a4e7f5bc3f5aa29e510a0e
# part
# 6beba2e17706b17be0b6ad3036c39a76
# SAS
# 49578c24ee5828427d2a64bcdfb2ad17
# Group
# fc2aa2a607530d8f0905374de102dc36
# 25-year
# 72e1f4679537fe4b4908de20abac4427
# history
# 5856989078d47dadd08fd89502df308d
# company
# aa3c7975fd99e252b969d7df4eac498d
# fatal
# 4aba16e84fabb6ae794ce066835d7fc0
# accident
# 05e36b1a620f472025c038cdcf1e404d
# hull
# f778a41584be87f8efa5d0007a8fdff6
# loss
# 6f0660920d779856fe452ad82e0a6df5
# McDonnell
# 83bf630338d9678d2902def3f5f94bab
# Douglas
# 05c98dc16815eec1bb8f1257fe5c03ce
# MD-80
# 978f061be09a3b689b49c71e1b32797e
# series
# f76805c116d372a615683a51b07e8bd4
# aircraft
# 7b45c7b9a19f5d08c0df2c350252b64a
# Spain
# f8d4ecda2e1cf5e54939429778f4e875
# deadliest
# 6ea970a867bc536bb67d6f13c678294e
# accident
# 8a9170ff9bbd282b01a5a2aec2394b28
# Avianca
# 78e93d1c36d7c74ff6fd03f5508b4e47
# Flight
# 5e5327c492a05d4fa8d81203f751561a
# accident
# 30b3bb3d5f5cce5ff36525e29acec66a
# Spanair
# 91bbe62425e26ae0129462d0af4fd55c
# already
# 826f0fde06a01e17cb47ec075e1e7872
# negative
# 8bb11e2a4b7633b7cdd47941a375cb15
# image
# 75c0206979e294dc5ad26f51cde49325
# time
# 00341c3165199fff2120d37ca00a7a56
# financial
# b8ae23e2706f27226d6bdd3feb44fcb3
# difficulties
# 7de01f2e451350a556ab73f5292880ad
# Spanair
# 331871f1e5b89d9c29fea25474e42364
# subsequently
# 7456b4114e9c8f6d48cfaebc1c722942
# operations
# e40c1b97a3048965a00b296864aa64bf
# January

# %%
print("Training data size:", len(train_data))
print("Example training instance:", train_data[0])
# Out:
# Training data size: 2913
# Example training instance: {'title': '2006 Pangandaran earthquake and tsunami', 'id': '8307a6b61b84d4eea42c1dd5e6e2cdba', 'content': [{'sentence': 'The 2006 Pangandaran earthquake and tsunami occurred on July 17 at along a subduction zone off the coast of west and central Java, a large and densely populated island in the Indonesian archipelago.', 'tokens': ['The', '2006', 'Pangandaran', 'earthquake', 'and', 'tsunami', 'occurred', 'on', 'July', '17', 'at', 'along', 'a', 'subduction', 'zone', 'off', 'the', 'coast', 'of', 'west', 'and', 'central', 'Java', ',', 'a', 'large', 'and', 'densely', 'populated', 'island', 'in', 'the', 'Indonesian', 'archipelago', '.']}, {'sentence': 'The shock had a moment magnitude of 7.7 and a maximum perceived intensity of IV ("Light") in Jakarta, the capital and largest city of Indonesia.', 'tokens': ['The', 'shock', 'had', 'a', 'moment', 'magnitude', 'of', '7.7', 'and', 'a', 'maximum', 'perceived', 'intensity', 'of', 'IV', '(', '``', 'Light', "''", ')', 'in', 'Jakarta', ',', 'the', 'capital', 'and', 'largest', 'city', 'of', 'Indonesia', '.']}, {'sentence': "There were no direct effects of the earthquake's shaking due to its low intensity, and the large loss of life from the event was due to the resulting tsunami, which inundated a portion of the Java coast that had been unaffected by the earlier 2004 Indian Ocean earthquake and tsunami that was off the coast of Sumatra.", 'tokens': ['There', 'were', 'no', 'direct', 'effects', 'of', 'the', 'earthquake', "'s", 'shaking', 'due', 'to', 'its', 'low', 'intensity', ',', 'and', 'the', 'large', 'loss', 'of', 'life', 'from', 'the', 'event', 'was', 'due', 'to', 'the', 'resulting', 'tsunami', ',', 'which', 'inundated', 'a', 'portion', 'of', 'the', 'Java', 'coast', 'that', 'had', 'been', 'unaffected', 'by', 'the', 'earlier', '2004', 'Indian', 'Ocean', 'earthquake', 'and', 'tsunami', 'that', 'was', 'off', 'the', 'coast', 'of', 'Sumatra', '.']}, {'sentence': 'The July 2006 earthquake was also centered in the Indian Ocean, from the coast of Java, and had a duration of more than three minutes.', 'tokens': ['The', 'July', '2006', 'earthquake', 'was', 'also', 'centered', 'in', 'the', 'Indian', 'Ocean', ',', 'from', 'the', 'coast', 'of', 'Java', ',', 'and', 'had', 'a', 'duration', 'of', 'more', 'than', 'three', 'minutes', '.']}, {'sentence': 'An abnormally slow rupture at the Sunda Trench and a tsunami that was unusually strong relative to the size of the earthquake were both factors that led to it being categorized as a tsunami earthquake.', 'tokens': ['An', 'abnormally', 'slow', 'rupture', 'at', 'the', 'Sunda', 'Trench', 'and', 'a', 'tsunami', 'that', 'was', 'unusually', 'strong', 'relative', 'to', 'the', 'size', 'of', 'the', 'earthquake', 'were', 'both', 'factors', 'that', 'led', 'to', 'it', 'being', 'categorized', 'as', 'a', 'tsunami', 'earthquake', '.']}, {'sentence': 'Several thousand kilometers to the southeast, surges of several meters were observed in northwestern Australia, but in Java the tsunami runups (height above normal sea level) were typically and resulted in the deaths of more than 600 people.', 'tokens': ['Several', 'thousand', 'kilometers', 'to', 'the', 'southeast', ',', 'surges', 'of', 'several', 'meters', 'were', 'observed', 'in', 'northwestern', 'Australia', ',', 'but', 'in', 'Java', 'the', 'tsunami', 'runups', '(', 'height', 'above', 'normal', 'sea', 'level', ')', 'were', 'typically', 'and', 'resulted', 'in', 'the', 'deaths', 'of', 'more', 'than', '600', 'people', '.']}, {'sentence': 'Other factors may have contributed to exceptionally high peak runups of on the small and mostly uninhabited island of Nusa Kambangan, just to the east of the resort town of Pangandaran, where damage was heavy and a large loss of life occurred.', 'tokens': ['Other', 'factors', 'may', 'have', 'contributed', 'to', 'exceptionally', 'high', 'peak', 'runups', 'of', 'on', 'the', 'small', 'and', 'mostly', 'uninhabited', 'island', 'of', 'Nusa', 'Kambangan', ',', 'just', 'to ...

# %%
import re

def preprocess_text(text):
    # Remove special characters and extra spaces
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

def preprocess_data(data):
    preprocessed_data = []
    for instance in data:
        content = instance['content']
        preprocessed_content = []
        for item in content:
            sentence = preprocess_text(item['sentence'])
            tokens = item['tokens']
            preprocessed_content.append({'sentence': sentence, 'tokens': tokens})
        instance['content'] = preprocessed_content
        preprocessed_data.append(instance)
    return preprocessed_data

# Preprocess training, validation, and test data
train_data = preprocess_data(train_data)
valid_data = preprocess_data(valid_data)
test_data = preprocess_data(test_data)

# Example: Print the preprocessed content of the first instance in the training data
print(train_data[0]['content'])
# Out:
# [{'sentence': 'The 2006 Pangandaran earthquake and tsunami occurred on July 17 at along a subduction zone off the coast of west and central Java a large and densely populated island in the Indonesian archipelago', 'tokens': ['The', '2006', 'Pangandaran', 'earthquake', 'and', 'tsunami', 'occurred', 'on', 'July', '17', 'at', 'along', 'a', 'subduction', 'zone', 'off', 'the', 'coast', 'of', 'west', 'and', 'central', 'Java', ',', 'a', 'large', 'and', 'densely', 'populated', 'island', 'in', 'the', 'Indonesian', 'archipelago', '.']}, {'sentence': 'The shock had a moment magnitude of 77 and a maximum perceived intensity of IV Light in Jakarta the capital and largest city of Indonesia', 'tokens': ['The', 'shock', 'had', 'a', 'moment', 'magnitude', 'of', '7.7', 'and', 'a', 'maximum', 'perceived', 'intensity', 'of', 'IV', '(', '``', 'Light', "''", ')', 'in', 'Jakarta', ',', 'the', 'capital', 'and', 'largest', 'city', 'of', 'Indonesia', '.']}, {'sentence': 'There were no direct effects of the earthquakes shaking due to its low intensity and the large loss of life from the event was due to the resulting tsunami which inundated a portion of the Java coast that had been unaffected by the earlier 2004 Indian Ocean earthquake and tsunami that was off the coast of Sumatra', 'tokens': ['There', 'were', 'no', 'direct', 'effects', 'of', 'the', 'earthquake', "'s", 'shaking', 'due', 'to', 'its', 'low', 'intensity', ',', 'and', 'the', 'large', 'loss', 'of', 'life', 'from', 'the', 'event', 'was', 'due', 'to', 'the', 'resulting', 'tsunami', ',', 'which', 'inundated', 'a', 'portion', 'of', 'the', 'Java', 'coast', 'that', 'had', 'been', 'unaffected', 'by', 'the', 'earlier', '2004', 'Indian', 'Ocean', 'earthquake', 'and', 'tsunami', 'that', 'was', 'off', 'the', 'coast', 'of', 'Sumatra', '.']}, {'sentence': 'The July 2006 earthquake was also centered in the Indian Ocean from the coast of Java and had a duration of more than three minutes', 'tokens': ['The', 'July', '2006', 'earthquake', 'was', 'also', 'centered', 'in', 'the', 'Indian', 'Ocean', ',', 'from', 'the', 'coast', 'of', 'Java', ',', 'and', 'had', 'a', 'duration', 'of', 'more', 'than', 'three', 'minutes', '.']}, {'sentence': 'An abnormally slow rupture at the Sunda Trench and a tsunami that was unusually strong relative to the size of the earthquake were both factors that led to it being categorized as a tsunami earthquake', 'tokens': ['An', 'abnormally', 'slow', 'rupture', 'at', 'the', 'Sunda', 'Trench', 'and', 'a', 'tsunami', 'that', 'was', 'unusually', 'strong', 'relative', 'to', 'the', 'size', 'of', 'the', 'earthquake', 'were', 'both', 'factors', 'that', 'led', 'to', 'it', 'being', 'categorized', 'as', 'a', 'tsunami', 'earthquake', '.']}, {'sentence': 'Several thousand kilometers to the southeast surges of several meters were observed in northwestern Australia but in Java the tsunami runups height above normal sea level were typically and resulted in the deaths of more than 600 people', 'tokens': ['Several', 'thousand', 'kilometers', 'to', 'the', 'southeast', ',', 'surges', 'of', 'several', 'meters', 'were', 'observed', 'in', 'northwestern', 'Australia', ',', 'but', 'in', 'Java', 'the', 'tsunami', 'runups', '(', 'height', 'above', 'normal', 'sea', 'level', ')', 'were', 'typically', 'and', 'resulted', 'in', 'the', 'deaths', 'of', 'more', 'than', '600', 'people', '.']}, {'sentence': 'Other factors may have contributed to exceptionally high peak runups of on the small and mostly uninhabited island of Nusa Kambangan just to the east of the resort town of Pangandaran where damage was heavy and a large loss of life occurred', 'tokens': ['Other', 'factors', 'may', 'have', 'contributed', 'to', 'exceptionally', 'high', 'peak', 'runups', 'of', 'on', 'the', 'small', 'and', 'mostly', 'uninhabited', 'island', 'of', 'Nusa', 'Kambangan', ',', 'just', 'to', 'the', 'east', 'of', 'the', 'resort', 'town', 'of', 'Pangandaran', ',', 'where', 'damage', 'was', 'heavy', 'and', 'a', 'large', 'loss', 'of', 'life', 'occu ...

# %%
import spacy

# Load English tokenizer, tagger, parser, NER, and word vectors
nlp = spacy.load("en_core_web_sm")

# Extract named entities from text
def extract_entities(text):
    doc = nlp(text)
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    return entities

# %%
# Parse dependencies from text
def parse_dependencies(text):
    doc = nlp(text)
    dependencies = [(token.text, token.dep_, token.head.text) for token in doc]
    return dependencies

# %%
# Rule-based extraction based on identified entities and dependencies

def load_triggers(dataset_file):
    triggers = []
    with jsonlines.open(dataset_file) as reader:
        for obj in reader:
            for event in obj['events']:
                for mention in event['mention']:
                    triggers.append(mention['trigger_word'])
    return triggers

# Extract event details from text, entities, and dependencies
def extract_event_details(text, entities, dependencies, triggers):
    event_details = {
        'location': None,
        'date': None,
        'time': None,
        'event_type': None
    }
    for trigger in triggers:
        if trigger in text:
            event_details['event_type'] = trigger
            break
    for entity, label in entities:
        if label == 'DATE':
            event_details['date'] = entity
        elif label == 'TIME':
            event_details['time'] = entity
        elif label == 'GPE':
            event_details['location'] = entity
        elif label == 'EVENT_TYPE':
            event_details['event_type'] = entity


    # Leverage Dependencies for Event Roles
    for token, dep, head_token in dependencies:
        if dep == 'nsubj' and head_token.lower() in ('held', 'conducted', 'organized', 'occurred', 'happened', 'took place'):
            event_details['event_type'] = head_token  # Extract potential event type
        elif dep == 'dobj' and head_token.lower() in ('held', 'conducted', 'organized', 'occurred', 'happened', 'took place'):
            event_details['event_type'] = head_token  # Extract potential event type
        elif dep == 'nmod' and head_token.lower() in ('held', 'conducted', 'organized', 'occurred', 'happened', 'took place'):
            if token.lower() in ('place', 'region', 'city'):
                event_details['location'] = head_token  # Extract potential location from prepositional phrases

    # Adjust event type based on context
    if event_details['event_type'] is None:
        for token, dep, head_token in dependencies:
            if dep == 'ROOT' and token.lower() in ('held', 'conducted', 'organized', 'occurred', 'happened', 'took place'):
                event_details['event_type'] = token  # Extract event type from root verb

    return event_details

# %%
def extract_event_information(input_text, triggers):
    # Preprocess the input text
    cleaned_text = preprocess_text(input_text)

    # Extract entities using NER
    entities = extract_entities(cleaned_text)

    # Parse dependencies using dependency parsing
    dependencies = parse_dependencies(cleaned_text)

    # Extract event details using rules based on entities, dependencies, and triggers
    event_details = extract_event_details(cleaned_text, entities, dependencies, triggers)

    return event_details

# %%
triggers = load_triggers('/content/drive/MyDrive/Dataset/train.jsonl')
text = "A strong earthquake struck California on February 29, 2024, at 10:00 AM."
event_details = extract_event_information(text, triggers)
print(event_details)
# Out:
# {'location': 'California', 'date': 'February 29 2024', 'time': '1000 AM', 'event_type': 'earthquake'}

# %%
# Example random input text
input_text2 = "A music festival took place in New York City on July 4, 2023, starting at 6 PM."
event_details2 = extract_event_information(input_text2, triggers)
print(event_details2)
# Out:
# {'location': 'New York City', 'date': 'July 4 2023', 'time': '6 PM', 'event_type': 'took place'}

# %%
input_text = "The annual conference on artificial intelligence and machine learning will be held in San Francisco from October 10th to October 12th, 2023."
event_details = extract_event_information(input_text, triggers)
print(event_details)
# Out:
# {'location': 'San Francisco', 'date': 'October 10th to October 12th 2023', 'time': None, 'event_type': 'ran'}

# %%
def calculate_accuracy(ground_truth, predictions):
    correct_predictions = 0
    total_instances = len(ground_truth)

    for i in range(total_instances):
        if ground_truth[i] == predictions[i]:
            correct_predictions += 1

    accuracy = (correct_predictions / total_instances) * 100
    return accuracy

# %%
def calculate_precision_recall_f1(ground_truth, predictions):
    true_positives = sum(1 for i in range(len(predictions)) if predictions[i] == 1 and ground_truth[i] == 1)
    false_positives = sum(1 for i in range(len(predictions)) if predictions[i] == 1 and ground_truth[i] == 0)
    false_negatives = sum(1 for i in range(len(predictions)) if predictions[i] == 0 and ground_truth[i] == 1)

    precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
    recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0

    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    return precision, recall, f1_score

# Example ground truth and predictions (binary classification: 1 for event, 0 for non-event)
ground_truth = [1, 0, 1, 1, 0, 1, 0, 1, 0, 0]
predictions = [1, 0, 1, 0, 1, 1, 0, 1, 0, 1]

# Calculate precision, recall, and F1 score
precision, recall, f1_score = calculate_precision_recall_f1(ground_truth, predictions)

print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1_score:.2f}")
# Out:
# Precision: 0.67
# Recall: 0.80
# F1 Score: 0.73
